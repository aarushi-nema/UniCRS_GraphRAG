# %%
import pandas as pd

# %%
community_df = pd.read_parquet(r"/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/create_final_community_reports.parquet")
community_df
# Out:
#                                  id  human_readable_id  community  parent  \
# 0  776d828c26dc47fcbaf5ee53dd51a4ee                  0          0      -1
# 1  ef56afcbd97745069e2bbbfcee968ddb                  1          1      -1
# 2  1bd54cf09ffd41c4a1310d9d4a466fb9                  2          2      -1
#
#    level                                              title  \
# 0      0  A Nightmare on Elm Street (1984) and Freddy Kr...
# 1      0  Horror Movies Community: A Dive into Fear and ...
# 2      0   A Quiet Place (2018) and John Krasinski's Impact
#
#                                              summary  \
# 0  This community centers around the 1984 horror ...
# 1  This community focuses on horror movies, inclu...
# 2  This community centers around the movie A Quie...
#
#                                         full_content  rank  \
# 0  # A Nightmare on Elm Street (1984) and Freddy ...   7.5
# 1  # Horror Movies Community: A Dive into Fear an...   7.5
# ...

# %%
df = pd.read_parquet('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/20250124-154316/artifacts/create_final_entities.parquet')
df
# Out:
#                                       id  human_readable_id  \
# 0   df1236e9-9944-49b3-b1aa-172c82808a96                  0
# 1   1e4cdb18-d928-4f8a-a204-388d389d9d8f                  1
# 2   59f565cf-020f-4281-9909-276680193939                  2
# 3   3a42fac3-bd95-474e-af89-ea5c84375558                  3
# 4   eacbb147-f231-4224-b7fb-7c3966944fd0                  4
# 5   b938857f-98c8-4464-b5b2-6b3327efa34a                  5
# 6   1283f800-4cfe-48fc-9fa9-ca6e9b742f60                  6
# 7   95c82565-7e0e-4857-b9b5-e1ef6bce2cf4                  7
# 8   63fd4009-0e59-4cc5-a823-508ec3645422                  8
# 9   ff6e0d1b-4a36-4a11-88a7-d0620db10735                  9
# 10  09e8890b-ed32-4002-beb4-1b427616b25a                 10
# 11  c73ffec2-207e-4dc5-b962-e093a735fd45                 11
# 12  69dc32f2-5023-4354-b0e9-dce332772f99                 12
# 13  cfc6dbab-0759-4b44-9f4c-21634f35e311                 13
# 14  05ddc5d6-d52b-4a6d-81c3-573a37c71f64                 14
#
# ...

# %%
import pandas as pd
import json


with open('entity2id.json', 'r') as f:
   entity2id = json.load(f)

# Map IDs and drop where mapped_id is -1
df['mapped_id'] = df['title'].map(lambda x: entity2id.get(x, -1))
df = df[df['mapped_id'] != -1]

# Save filtered dataframe if needed
# df.to_parquet('filtered_output.parquet')

# %%
df = pd.read_parquet('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/20250124-154316/artifacts/create_final_entities.parquet')
df
# Out:
#                                       id  human_readable_id  \
# 0   df1236e9-9944-49b3-b1aa-172c82808a96                  0
# 1   1e4cdb18-d928-4f8a-a204-388d389d9d8f                  1
# 2   59f565cf-020f-4281-9909-276680193939                  2
# 3   3a42fac3-bd95-474e-af89-ea5c84375558                  3
# 4   eacbb147-f231-4224-b7fb-7c3966944fd0                  4
# 5   b938857f-98c8-4464-b5b2-6b3327efa34a                  5
# 6   1283f800-4cfe-48fc-9fa9-ca6e9b742f60                  6
# 7   95c82565-7e0e-4857-b9b5-e1ef6bce2cf4                  7
# 8   63fd4009-0e59-4cc5-a823-508ec3645422                  8
# 9   ff6e0d1b-4a36-4a11-88a7-d0620db10735                  9
# 10  09e8890b-ed32-4002-beb4-1b427616b25a                 10
# 11  c73ffec2-207e-4dc5-b962-e093a735fd45                 11
# 12  69dc32f2-5023-4354-b0e9-dce332772f99                 12
# 13  cfc6dbab-0759-4b44-9f4c-21634f35e311                 13
# 14  05ddc5d6-d52b-4a6d-81c3-573a37c71f64                 14
#
# ...

# %%
df = pd.read_parquet('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/20250124-154316/artifacts/create_final_relationships.parquet')
df
# Out:
#                                       id  human_readable_id  \
# 0   73cf161d-9bcd-400b-8967-44c63b413236                  0
# 1   0fc7df49-b0ea-49a5-ab36-5ddd71fb0462                  1
# 2   6cc98cac-4a53-4a4a-bc42-dd3777590038                  2
# 3   69ab4809-2d72-49d1-a25f-19efdbbae4ae                  3
# 4   c6e4af47-a2c4-4e5a-beb9-e3fe230e3c31                  4
# 5   0ee59714-65df-4733-9f0f-55ed7699970b                  5
# 6   f958b2b1-69d4-49c8-b9e4-ff0f6752a4d4                  6
# 7   bf8817dc-da19-44d1-bfb5-87b10116b9bf                  7
# 8   9428e2e0-ecee-4b40-b61c-0a4ba7d9b34b                  8
# 9   9917a5ff-18a3-4760-b2ea-ba178780d22b                  9
# 10  a3678bce-d742-4e17-807e-27abc014efdf                 10
# 11  48866c40-afb1-4afb-a511-15abeffefb3f                 11
# 12  73dabdb2-40eb-4a1f-a4c9-a800f436531c                 12
#
#                            source                        target  \
# ...
