# %%
import pandas as pd
import json
import time
import subprocess
import torch
from model_prompt import KGPrompt
from collections import defaultdict
from dataset_dbpedia import DBpedia

import sys
sys.path.append('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG')

from pre_rec_dataset_dbpedia import Dialogue_DBpedia
from dataset_dbpedia import DBpedia

# %%
# with open('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/dialogues/test_data copy.txt', 'r') as file:
#     for i,line in enumerate(file):
#         print("Processing line ", i)
#         line = line.strip()
#         with open('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/input/current_line.txt', 'w') as current_file:
#            current_file.write(line)

#         # Run the graphrag command and wait for it to complete
#         process = subprocess.run(['graphrag', 'index', '--root', '/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/'], 
#                               capture_output=True,  # Capture the output
#                               text=True)  # Convert output to string
        
#         if process.returncode == 0:
#             print("Command completed successfully")

# %%
# Read the generated parquet files
entities_df = pd.read_parquet('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/create_final_entities.parquet')
relationships_df = pd.read_parquet('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/output/create_final_relationships.parquet')

print("Found entities:", len(entities_df))
print("First 5 entities", entities_df['title'])
print("Found relationships:", len(relationships_df))
# Out:
# Found entities: 16
# First 5 entities 0      A NIGHTMARE ON ELM STREET (1984)
# 1                HAPPY DEATH DAY (2017)
# 2     THE LAST HOUSE ON THE LEFT (1972)
# 3                  A QUIET PLACE (2018)
# 4                      ANNABELLE (2014)
# 5                     THE FOREST (2016)
# 6                  HOT TUB TIME MACHINE
# 7                 SUPER TROOPERS (2001)
# 8                 IDENTITY THIEF (2013)
# 9                       THE HEAT (2013)
# 10                               HORROR
# 11                               COMEDY
# 12                       JOHN KRASINSKI
# 13                        JASON BATEMAN
# 14                     MELISSA MCCARTHY
# 15                       FREDDY KRUEGER
# Name: title, dtype: object
# Found relationships: 15

# %%
# --------- Assign Relationship Label --------------

# Prepare mappings for entities
entity_id_map = dict(zip(entities_df['title'], entities_df['human_readable_id']))
entity_type_map = dict(zip(entities_df['title'], entities_df['type']))

# Create Relationships DataFrame with initial mappings
relationships_clean_df = relationships_df.assign(
    entity_id_source=relationships_df['source'].map(entity_id_map),
    entity_type_source=relationships_df['source'].map(entity_type_map),
    entity_id_target=relationships_df['target'].map(entity_id_map),
    entity_type_target=relationships_df['target'].map(entity_type_map)
)

# Define relationship type mapping with IDs
relationship_type_mapping = {
    ('MOVIE', 'ACTOR'): ('features', 0),
    ('ACTOR', 'MOVIE'): ('acted_in', 1),
    ('MOVIE', 'GENRE'): ('belongs_to_genre', 2),
    ('GENRE', 'MOVIE'): ('categorizes', 3),
    ('MOVIE', 'DIRECTOR'): ('directed_by', 4),
    ('DIRECTOR', 'MOVIE'): ('directed', 5),
    ('MOVIE', 'CHARACTER'): ('has_character', 6),
    ('CHARACTER', 'MOVIE'): ('featured_in', 7),
    ('ACTOR', 'CHARACTER'): ('portrays', 8),
    ('CHARACTER', 'ACTOR'): ('portrayed_by', 9),
    ('GENRE', 'DIRECTOR'): ('prefers_to_direct', 10),
    ('DIRECTOR', 'GENRE'): ('has_preference_for', 11),
    ('CHARACTER', 'DIRECTOR'): ('created_by', 12),
    ('DIRECTOR', 'CHARACTER'): ('conceived', 13),
    ('MOVIE', 'MOVIE'): ('similar', 14)
}

# Reverse the relationships and add them to the original DataFrame
relationships_reversed_df = relationships_clean_df.rename(columns={
    'entity_id_source': 'entity_id_target',
    'entity_name_source': 'entity_name_target',
    'entity_type_source': 'entity_type_target',
    'entity_id_target': 'entity_id_source',
    'entity_name_target': 'entity_name_source',
    'entity_type_target': 'entity_type_source'
}).copy()

# Combine the original and reversed relationships
relationships_combined_df = pd.concat([relationships_clean_df, relationships_reversed_df], ignore_index=True)

# Assign relationship types and IDs based on source and target entity types
relationships_combined_df[['relationship_type', 'relationship_type_id']] = relationships_combined_df.apply(
    lambda row: pd.Series(relationship_type_mapping.get(
        (row['entity_type_source'], row['entity_type_target']), ('unknown', -1)
    )),
    axis=1
)

kg_df = relationships_combined_df[['entity_id_source', 'source', 'entity_type_source',  'entity_id_target', 'target', 'entity_type_target', 'relationship_type', 'relationship_type_id']]

# %%
# --------- Create file dialogue_subkg.json --------------

# Group data by source entity
json_structure = defaultdict(list)

# Replace 'kg_df' with the DataFrame containing the KG relationships
for _, row in kg_df.iterrows():
    source_id = row['entity_id_source']
    target_id = row['entity_id_target']
    relationship_id = row['relationship_type_id']
    if relationship_id != -1:  # Only include valid relationships
        json_structure[source_id].append([relationship_id, target_id])

# Convert the defaultdict to a regular dictionary
json_output = {str(source): [[rel_id, target] for rel_id, target in targets]
               for source, targets in json_structure.items()}

# Save the compact JSON structure to a file
compact_json_file_path = "/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/dialogue_subkg.json"
with open(compact_json_file_path, "w") as json_file:
    json.dump(json_output, json_file, separators=(',', ':'))

# %%
# --------- Create file dialogue_entity2id.json --------------

# Create a mapping of entity: id in the required format
entity_id_mapping = {
    f"{row['title']}" : row['human_readable_id']
    for _, row in entities_df.iterrows()
}

# Save the mapping as a JSON file
entity_json_file_path = "/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/dialogue_entity2id.json"
with open(entity_json_file_path, "w") as json_file:
    json.dump(entity_id_mapping, json_file, separators=(',', ':'))

# %%
# --------- Create file dialogue_item_ids.json --------------
item_set = set()

# store entity ids in item_set
item_set = set(entities_df['human_readable_id'].tolist())

with open('/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/dialogue_item_ids.json', 'w', encoding='utf-8') as f:
    json.dump(list(item_set), f, ensure_ascii=False)

# %%
# --------- GET DIALOGUE EMBEDDINGS VIA RGCN --------------

def get_dialogue_embeddings():
    """
    Get RGCN embeddings for a single dialogue's KG
    
    Args:
        dialogue_path: Path to folder containing the dialogue's KG files
                      (dbpedia_subkg.json, entity2id.json, relation2id.json, item_ids.json)
    """
    # Initialize DBpedia with dialogue data
    kg = Dialogue_DBpedia(debug=True).get_entity_kg_info()
    
    # Initialize KGPrompt (which contains the RGCN)
    prompt_encoder = KGPrompt(
        hidden_size=768,              # GPT2 hidden size
        token_hidden_size=768,        # Same as hidden_size
        n_head=12,                    # Number of attention heads
        n_layer=12,                   # Number of layers
        n_block=2,                    # Number of blocks
        n_entity=kg['num_entities'],  # From your KG
        num_relations=kg['num_relations'],  # From your KG
        num_bases=8,                  # Number of bases for relation weights
        edge_index=kg['edge_index'],  # From your KG
        edge_type=kg['edge_type']     # From your KG
    )
    
    # Get embeddings
    with torch.no_grad():
        entity_embeddings = prompt_encoder.get_entity_embeds()
    
    return entity_embeddings, prompt_encoder, kg

# Example usage
if __name__ == "__main__":
    
    # Get embeddings
    embeddings, encoder, kg_info = get_dialogue_embeddings()
    
    print(f"Number of entities: {kg_info['num_entities']}")
    print(f"Number of relations: {kg_info['num_relations']}")
    print(f"Embedding shape: {embeddings.shape}")
    
    # Save the embeddings if needed
    torch.save(embeddings, f"/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/entity_embeddings.pt")
# Out:
# 2025-02-22 15:00:27.277 | DEBUG    | pre_rec_dataset_dbpedia:_process_entity_kg:43 - #edge: 16, #relation: 15, #entity: 17, #item: 16
# node_embeds device: cpu
# edge_index device: cpu
# edge_type device: cpu
# node_embeds shape: torch.Size([17, 384])
# edge_index shape: torch.Size([2, 16])
# edge_type shape: torch.Size([16])
# Number of entities: 17
# Number of relations: 15
# Embedding shape: torch.Size([17, 768])

# %%
# --------- GET KG EMBEDDINGS VIA RGCN --------------

def get_kg_embeddings():
    """
    Get RGCN embeddings for a single dialogue's KG
    
    Args:
        dialogue_path: Path to folder containing the dialogue's KG files
                      (dbpedia_subkg.json, entity2id.json, relation2id.json, item_ids.json)
    """
    # Initialize DBpedia with dialogue data
    kg = DBpedia(debug=True).get_entity_kg_info()
    
    # Initialize KGPrompt (which contains the RGCN)
    prompt_encoder = KGPrompt(
        hidden_size=768,              # GPT2 hidden size
        token_hidden_size=768,        # Same as hidden_size
        n_head=12,                    # Number of attention heads
        n_layer=12,                   # Number of layers
        n_block=2,                    # Number of blocks
        n_entity=kg['num_entities'],  # From your KG
        num_relations=kg['num_relations'],  # From your KG
        num_bases=8,                  # Number of bases for relation weights
        edge_index=kg['edge_index'],  # From your KG
        edge_type=kg['edge_type']     # From your KG
    )
    
    # Get embeddings
    with torch.no_grad():
        entity_embeddings = prompt_encoder.get_entity_embeds()
    
    return entity_embeddings, prompt_encoder, kg

# Example usage
if __name__ == "__main__":
    
    # Get embeddings
    embeddings, encoder, kg_info = get_kg_embeddings()
    
    print(f"Number of entities: {kg_info['num_entities']}")
    print(f"Number of relations: {kg_info['num_relations']}")
    print(f"Embedding shape: {embeddings.shape}")
    
    # Save the embeddings if needed
    torch.save(embeddings, f"/home/Nema/UniCRS_GraphRAG/Recommendation_GraphRAG/entity_embeddings.pt")
# Out:
# 2025-02-22 15:00:46.548 | DEBUG    | dataset_dbpedia:_process_entity_kg:44 - #edge: 45180, #relation: 15, #entity: 11861, #item: 4776
# node_embeds device: cpu
# edge_index device: cpu
# edge_type device: cpu
# node_embeds shape: torch.Size([11861, 384])
# edge_index shape: torch.Size([2, 45180])
# edge_type shape: torch.Size([45180])
# Number of entities: 11861
# Number of relations: 15
# Embedding shape: torch.Size([11861, 768])

# %%
def get_both_embeddings():
    """Get embeddings for both KGs using the same RGCN"""
    
    # First get the main KG RGCN
    print("Initializing main KG...")
    main_kg = DBpedia(debug=True).get_entity_kg_info()
    
    # Initialize RGCN with main KG
    prompt_encoder = KGPrompt(
        hidden_size=768,
        token_hidden_size=768,
        n_head=12,
        n_layer=12,
        n_block=2,
        n_entity=main_kg['num_entities'],
        num_relations=main_kg['num_relations'],
        num_bases=8,
        edge_index=main_kg['edge_index'],
        edge_type=main_kg['edge_type']
    )
    
    # Get main KG embeddings
    with torch.no_grad():
        main_embeddings = prompt_encoder.get_entity_embeds()
    
    print("Getting dialogue KG...")
    dialogue_kg = Dialogue_DBpedia(debug=True).get_entity_kg_info()
    
    # Store original graph info
    orig_edge_index = prompt_encoder.edge_index
    orig_edge_type = prompt_encoder.edge_type
    
    # Temporarily replace with dialogue subgraph
    prompt_encoder.edge_index.data = dialogue_kg['edge_index']
    prompt_encoder.edge_type.data = dialogue_kg['edge_type']
    
    # Get dialogue embeddings using same RGCN
    with torch.no_grad():
        dialogue_embeddings = prompt_encoder.get_entity_embeds()
    
    # Restore original graph
    prompt_encoder.edge_index.data = orig_edge_index
    prompt_encoder.edge_type.data = orig_edge_type
    
    return dialogue_embeddings, main_embeddings, dialogue_kg, main_kg

# %%
import torch
import torch.nn.functional as F
import networkx as nx
from typing import Dict, List, Set, Tuple

def extract_relevant_subgraph(dialogue_embeddings: torch.Tensor, 
                            kg_embeddings: torch.Tensor,
                            main_kg: Dict,
                            dialogue_entities: List[str],
                            similarity_threshold: float = 0.7,
                            top_k: int = 5,
                            hop_size: int = 2) -> Tuple[torch.Tensor, torch.Tensor]:
    """
    Extract a subgraph from main KG based on dialogue entity similarities
    
    Args:
        dialogue_embeddings: Embeddings from dialogue KG
        kg_embeddings: Embeddings from main KG
        main_kg: Main KG info containing edge_index and edge_type
        dialogue_entities: List of dialogue entity titles
        similarity_threshold: Minimum similarity score to consider
        top_k: Number of similar entities to consider per dialogue entity
        hop_size: Number of hops to expand from similar entities
    
    Returns:
        Tuple of (edge_index, edge_type) for the extracted subgraph
    """
    # Normalize embeddings
    dialogue_embeddings_norm = F.normalize(dialogue_embeddings, p=2, dim=1)
    kg_embeddings_norm = F.normalize(kg_embeddings, p=2, dim=1)
    
    # Find similar entities
    similar_entity_ids = set()
    for dialogue_emb in dialogue_embeddings_norm:
        # Compute similarities with all KG entities
        similarities = F.cosine_similarity(dialogue_emb.unsqueeze(0), kg_embeddings_norm)
        
        # Get top-k similar entities
        scores, indices = torch.topk(similarities, k=min(top_k, len(kg_embeddings_norm)))
        
        # Add entities above threshold
        for score, idx in zip(scores, indices):
            if score >= similarity_threshold:
                similar_entity_ids.add(idx.item())
    
    print(f"Found {len(similar_entity_ids)} similar entities")
    
    # Convert main KG to networkx for easier neighbor extraction
    edge_index = main_kg['edge_index']
    edge_type = main_kg['edge_type']
    
    G = nx.Graph()
    for i in range(edge_index.size(1)):
        src = edge_index[0, i].item()
        dst = edge_index[1, i].item()
        G.add_edge(src, dst)
    
    # Expand subgraph by hop_size
    expanded_entities = similar_entity_ids.copy()
    for _ in range(hop_size):
        entities_to_add = set()
        for entity_id in expanded_entities:
            if entity_id in G:
                neighbors = set(G.neighbors(entity_id))
                entities_to_add.update(neighbors)
        expanded_entities.update(entities_to_add)
    
    print(f"Expanded to {len(expanded_entities)} entities after {hop_size} hops")
    
    # Extract edges for subgraph
    subgraph_edges = []
    subgraph_types = []
    
    for i in range(edge_index.size(1)):
        src = edge_index[0, i].item()
        dst = edge_index[1, i].item()
        if src in expanded_entities and dst in expanded_entities:
            subgraph_edges.append([src, dst])
            subgraph_types.append(edge_type[i].item())
    
    # Convert to tensors
    subgraph_edge_index = torch.tensor(subgraph_edges, dtype=torch.long).t()
    subgraph_edge_type = torch.tensor(subgraph_types, dtype=torch.long)
    
    print(f"Extracted subgraph has {len(subgraph_types)} edges")
    
    return subgraph_edge_index, subgraph_edge_type

# Get both embeddings using same RGCN
dialogue_embeddings, kg_embeddings, dialogue_kg, main_kg = get_both_embeddings()

# Get dialogue entity titles
entity_titles = entities_df['title'].tolist()

# Extract subgraph
subgraph_edge_index, subgraph_edge_type = extract_relevant_subgraph(
    dialogue_embeddings,
    kg_embeddings,
    main_kg,
    entity_titles,
    similarity_threshold=0.5,
    top_k=5,
    hop_size=1
)

# Print some statistics about the extracted subgraph
print("\nSubgraph Statistics:")
print(f"Number of edges: {subgraph_edge_type.size(0)}")
print(f"Number of unique entities: {len(torch.unique(subgraph_edge_index))}")
print(f"Number of unique relation types: {len(torch.unique(subgraph_edge_type))}")

# Optionally, print some example edges
print("\nExample edges in subgraph:")
for i in range(min(5, subgraph_edge_type.size(0))):
    src = subgraph_edge_index[0, i].item()
    dst = subgraph_edge_index[1, i].item()
    rel = subgraph_edge_type[i].item()
    print(f"Entity {src} -> Relation {rel} -> Entity {dst}")
# Out:
# 2025-02-22 15:44:38.390 | DEBUG    | dataset_dbpedia:_process_entity_kg:44 - #edge: 45180, #relation: 15, #entity: 11861, #item: 4776
# Initializing main KG...
# node_embeds device: cpu
# edge_index device: cpu
# edge_type device: cpu
# node_embeds shape: torch.Size([11861, 384])
# edge_index shape: torch.Size([2, 45180])
# edge_type shape: torch.Size([45180])
# 2025-02-22 15:44:39.750 | DEBUG    | pre_rec_dataset_dbpedia:_process_entity_kg:43 - #edge: 16, #relation: 15, #entity: 17, #item: 16
# Getting dialogue KG...
# node_embeds device: cpu
# edge_index device: cpu
# edge_type device: cpu
# node_embeds shape: torch.Size([11861, 384])
# edge_index shape: torch.Size([2, 16])
# edge_type shape: torch.Size([16])
# Found 11825 similar entities
# Expanded to 11861 entities after 1 hops
# Extracted subgraph has 45180 edges
#
# Subgraph Statistics:
# Number of edges: 45180
# Number of unique entities: 6181
# Number of unique relation types: 13
#
# Example edges in subgraph:
# Entity 171 -> Relation 5 -> Entity 7435
# Entity 10402 -> Relation 3 -> Entity 2561
# Entity 131 -> Relation 1 -> Entity 303
# Entity 1469 -> Relation 1 -> Entity 2437
# Entity 754 -> Relation 2 -> Entity 9008

# %%
import torch
import torch.nn.functional as F
from typing import Dict, List, Tuple
import pandas as pd
import numpy as np

def get_both_embeddings():
    """Get embeddings for both KGs using the same RGCN"""
    
    # First get the main KG RGCN
    print("Initializing main KG...")
    main_kg = DBpedia(debug=True).get_entity_kg_info()
    
    # Initialize RGCN with main KG
    prompt_encoder = KGPrompt(
        hidden_size=768,
        token_hidden_size=768,
        n_head=12,
        n_layer=12,
        n_block=2,
        n_entity=main_kg['num_entities'],
        num_relations=main_kg['num_relations'],
        num_bases=8,
        edge_index=main_kg['edge_index'],
        edge_type=main_kg['edge_type']
    )
    
    # Get main KG embeddings
    with torch.no_grad():
        main_embeddings = prompt_encoder.get_entity_embeds()
    
    print("Getting dialogue KG...")
    dialogue_kg = Dialogue_DBpedia(debug=True).get_entity_kg_info()
    
    # Store original graph info
    orig_edge_index = prompt_encoder.edge_index
    orig_edge_type = prompt_encoder.edge_type
    
    # Temporarily replace with dialogue subgraph
    prompt_encoder.edge_index.data = dialogue_kg['edge_index']
    prompt_encoder.edge_type.data = dialogue_kg['edge_type']
    
    # Get dialogue embeddings using same RGCN
    with torch.no_grad():
        dialogue_embeddings = prompt_encoder.get_entity_embeds()
    
    # Restore original graph
    prompt_encoder.edge_index.data = orig_edge_index
    prompt_encoder.edge_type.data = orig_edge_type
    
    return dialogue_embeddings, main_embeddings, dialogue_kg, main_kg

def match_entities(dialogue_embeddings, kg_embeddings, entity_titles, 
                  similarity_threshold=0.5, top_k=3):
    """Match entities based on embedding similarity"""
    
    dialogue_embeddings_norm = F.normalize(dialogue_embeddings, p=2, dim=1)
    kg_embeddings_norm = F.normalize(kg_embeddings, p=2, dim=1)
    
    matches = []
    for i, dialogue_emb in enumerate(dialogue_embeddings_norm):
        # Get entity title
        entity_title = entity_titles[i] if i < len(entity_titles) else f"Entity_{i}"
        
        # Compute similarities
        similarities = F.cosine_similarity(dialogue_emb.unsqueeze(0), kg_embeddings_norm)
        
        # Get top matches
        scores, indices = torch.topk(similarities, k=min(top_k, len(kg_embeddings_norm)))
        
        entity_matches = []
        for score, idx in zip(scores, indices):
            score = score.item()
            if score >= similarity_threshold:
                entity_matches.append({
                    'similarity_score': score,
                    'kg_entity_idx': idx.item()
                })
        
        matches.append({
            'dialogue_entity_idx': i,
            'entity_title': entity_title,
            'matches': entity_matches
        })
        
    return matches

# Get embeddings using same RGCN
dialogue_embeddings, kg_embeddings, dialogue_kg, main_kg = get_both_embeddings()

# Get entity titles
entity_titles = entities_df['title'].tolist()

# Match entities
matches = match_entities(dialogue_embeddings, kg_embeddings, entity_titles)

# Print results
print("\nEntity Matching Results:")
for match in matches:
    print(f"\nDialogue Entity: {match['entity_title']}")
    if match['matches']:
        print("Top matches:")
        for m in match['matches']:
            kg_idx = m['kg_entity_idx']
            score = m['similarity_score']
            print(f"  - KG Entity {kg_idx} (similarity: {score:.3f})")
    else:
        print("No matches found above threshold")
# Out:
# 2025-02-22 15:10:34.522 | DEBUG    | dataset_dbpedia:_process_entity_kg:44 - #edge: 45180, #relation: 15, #entity: 11861, #item: 4776
# Initializing main KG...
# node_embeds device: cpu
# edge_index device: cpu
# edge_type device: cpu
# node_embeds shape: torch.Size([11861, 384])
# edge_index shape: torch.Size([2, 45180])
# edge_type shape: torch.Size([45180])
# 2025-02-22 15:10:35.771 | DEBUG    | pre_rec_dataset_dbpedia:_process_entity_kg:43 - #edge: 16, #relation: 15, #entity: 17, #item: 16
# Getting dialogue KG...
# node_embeds device: cpu
# edge_index device: cpu
# edge_type device: cpu
# node_embeds shape: torch.Size([11861, 384])
# edge_index shape: torch.Size([2, 16])
# edge_type shape: torch.Size([16])
#
# Entity Matching Results:
#
# Dialogue Entity: A NIGHTMARE ON ELM STREET (1984)
# Top matches:
#   - KG Entity 6216 (similarity: 0.953)
#   - KG Entity 0 (similarity: 0.951)
#   - KG Entity 9384 (similarity: 0.950)
#
# Dialogue Entity: HAPPY DEATH DAY (2017)
# Top matches:
#   - KG Entity 2511 (similarity: 0.950)
#   - KG Entity 11670 (similarity: 0.948)
#   - KG Entity 8252 (similarity: 0.948)
#
# Dialogue Entity: THE LAST HOUSE ON THE LEFT (1972)
# Top matches:
#   - KG Entity 2 (similarity: 0.992)
#   - KG Entity 10721 (similarity: 0.950)
#   - KG Entity 4350 (similarity: 0.949)
#
# Dialogue Entity: A QUIET PLACE (2018)
# Top matches:
#   - KG Entity 3 (similarity: 0.969)
#   - KG Entity 10718 (similarity: 0.931)
#   - KG Entity 3873 (similarity: 0.931)
#
# Dialogue Entity: ANNABELLE (2014)
# Top matches:
#   - KG Entity 10442 (similarity: 0.952)
#   - KG Entity 1368 (similarity: 0.951)
#   - KG Entity 9235 (similarity: 0.951)
#
# Dialogue Entity: THE FOREST (2016)
# Top matches:
#   - KG Entity 8566 (similarity: 0.952)
#   - KG Entity 11325 (similarity: 0.952)
#   - KG Entity 3887 (similarity: 0.950)
#
# Dialogue Entity: HOT TUB TIME MACHINE
# Top matches:
#   - KG Entity 6 (similarity: 0.985)
#   - KG Entity 1546 (similarity: 0.954)
#   - KG Entity 8424 (similarity: 0.953)
#
# Dialogue Entity: SUPER TROOPERS (2001)
# Top matches:
#   - KG Entity 9079 (similarity: 0.947)
#   - KG Entity 10916 (similarity: 0.947)
#   - KG Entity 10442 (similarity: 0.947)
#
# Dialogue Entity: IDENTITY THIEF (2013)
# Top matches:
#   - KG Entity 9927 (similarity: 0.941)
#   - KG Entity 741 (similarity: 0.941)
#   - KG Entity 11630 (similarity: 0.938)
#
# Dialogue Entity: THE HEAT (2013)
# Top matches:
#   - KG Entity 9 (similarity: 0.935)
#   - KG Entity 8395 (similarity: 0.930)
#   - KG Entity 2289 (similarity: 0.930)
#
# Dialogue Entity: HORROR
# Top matches:
#   - KG Entity 7978 (similarity: 0.951)
#   - KG Entity 9096 (similarity: 0.950)
#   - KG Entity 5124 (similarity: 0.949)
#
# Dialogue Entity: COMEDY
# Top matches:
#   - KG Entity 11 (similarity: 0.972)
#   - KG Entity 8371 (similarity: 0.951)
#   - KG Entity 4106 (similarity: 0.950)
#
# Dialogue Entity: JOHN KRASINSKI
# Top matches:
#   - KG Entity 3453 (similarity: 0.939)
#   - KG Entity 12 (similarity: 0.939)
#   - KG Entity 2104 (similarity: 0.939)
#
# Dialogue Entity: JASON BATEMAN
# Top matches:
#   - KG Entity 8252 (similarity: 0.935)
#   - KG Entity 9419 (similarity: 0.932)
#   - KG Entity 318 (similarity: 0.932)
#
# Dialogue Entity: MELISSA MCCARTHY
# Top matches:
#   - KG Entity 14 (similarity: 0.968)
#   - KG Entity 11428 (similarity: 0.945)
#   - KG Entity 11388 (similarity: 0.941)
#
# Dialogue Entity: FREDDY KRUEGER
# Top matches:
#   - KG Entity 15 (similarity: 0.976)
#   - KG Entity 6756 (similarity: 0.952)
#   - KG Entity 10850 (similarity: 0.949)
#
# Dialogue Entity: Entity_16
# Top matches:
#   - KG Entity 16 (similarity: 0.989)
#   - KG Entity 11692 (similarity: 0.953)
#   - KG Entity 7510 (similarity: 0.951)
#
# Dialogue Entity: Entity_17
# Top matches:
#   - KG Entity 17 (similarity: 0.973)
#   - KG Entity 2807 (similarity: 0.950)
#   - KG Entity 7748 (similarity: 0.949)
#
# Dialogue Entity: Entity_18
# Top matches:
#   - KG Entity 18 (similarity: 0.990)
#   - KG Entity 4918 (similarity: 0.956)
#   - KG Entity 10511 (similarity: 0.956)
#
# Dialogue Entity: Entity_19
# Top matches:
#   - KG Entity 19 (similarity: 0.958)
#   - KG Entity 8810 (similarity: 0.948)
#   - KG Entity 2231 (similarity: 0.948)
#
# Dialogue Entity: Entity_20
# Top matches:
#   - KG Entity 20 (similarity: 0.990)
#   - KG Entity 5780 (similarity: 0.947)
#   - KG Entity 298 (similarity: 0.947)
#
# Dialogue Entity: Entity_21
# Top matches:
#   - KG Entity 21 (similarity: 0.957)
#   - KG Entity 2410 (similarity: 0.953)
#   - KG Entity 11833 (similarity: 0.952)
#
# Dialogue Entity: Entity_22
# Top matches:
#   - KG Entity 22 (similarity: 0.989)
#   - KG Entity 11847 (similarity: 0.949)
#   - KG Entity 5117 (similarity: 0.946)
#
# Dialogue Entity: Entity_23
# Top matches:
#   - KG Entity 23 (similarity: 0.977)
#   - KG Entity 1317 (similarity: 0.950)
#   - KG Entity 8805 (similarity: 0.950)
#
# Dialogue Entity: Entity_24
# Top matches:
#   - KG Entity 4258 (similarity: 0.950)
#   - KG Entity 24 (similarity: 0.950)
#   - KG Entity 8659 (similarity: 0.948)
#
# Dialogue Entity: Entity_25
# Top matches:
#   - KG Entity 25 (similarity: 0.968)
#   - KG Entity 9079 (similarity: 0.953)
#   - KG Entity 9297 (similarity: 0.949)
#
# Dialogue Entity: Entity_26
# Top matches:
#   - KG Entity 26 (similarity: 0.984)
#   - KG Entity 9714 (similarity: 0.946)
#   - KG Entity 2104 (similarity: 0.945)
#
# Dialogue Entity: Entity_27
# Top matches:
#   - KG Entity 27 (similarity: 0.995)
#   - KG Entity 5361 (similarity: 0.948)
#   - KG Entity 2505 (similarity: 0.948)
#
# Dialogue Entity: Entity_28
# Top matches:
#   - KG Entity 28 (similarity: 1.000)
#   - KG Entity 178 (similarity: 0.950)
#   - KG Entity 7993 (similarity: 0.950)
#
# Dialogue Entity: Entity_29
# Top matches:
#   - KG Entity 29 (similarity: 0.965)
#   - KG Entity 11403 (similarity: 0.947)
#   - KG Entity 1483 (similarity: 0.947)
#
# Dialogue Entity: Entity_30
# Top matches:
#   - KG Entity 10442 (similarity: 0.953)
#   - KG Entity 8094 (similarity: 0.953)
#   - KG Entity 9079 (similarity: 0.953)
#
# Dialogue Entity: Entity_31
# Top matches:
#   - KG Entity 31 (similarity: 0.959)
#   - KG Entity 11366 (similarity: 0.948)
#   - KG Entity 7302 (similarity: 0.947)
#
# Dialogue Entity: Entity_32
# Top matches:
#   - KG Entity 32 (similarity: 0.990)
#   - KG Entity 1323 (similarity: 0.950)
#   - KG Entity 923 (similarity: 0.948)
#
# Dialogue Entity: Entity_33
# Top matches:
#   - KG Entity 33 (similarity: 1.000)
#   - KG Entity 3701 (similarity: 0.951)
#   - KG Entity 11107 (similarity: 0.951)
#
# Dialogue Entity: Entity_34
# Top matches:
#   - KG Entity 34 (similarity: 0.972)
#   - KG Entity 10741 (similarity: 0.950)
#   - KG Entity 8491 (similarity: 0.949)
#
# Dialogue Entity: Entity_35
# Top matches:
#   - KG Entity 35 (similarity: 0.991)
#   - KG Entity 9060 (similarity: 0.947)
#   - KG Entity 8330 (similarity: 0.946)
#
# Dialogue Entity: Entity_36
# Top matches:
#   - KG Entity 36 (similarity: 0.959)
#   - KG Entity 10370 (similarity: 0.956)
#   - KG Entity 7138 (similarity: 0.954)
#
# Dialogue Entity: Entity_37
# Top matches:
#   - KG Entity 37 (similarity: 0.972)
#   - KG Entity 4132 (similarity: 0.950)
#   - KG Entity 9080 (similarity: 0.949)
#
# Dialogue Entity: Entity_38
# Top matches:
#   - KG Entity 38 (similarity: 1.000)
#   - KG Entity 9815 (similarity: 0.952)
#   - KG Entity 4527 (similarity: 0.950)
#
# Dialogue Entity: Entity_39
# Top matches:
#   - KG Entity 39 (similarity: 1.000)
#   - KG Entity 9702 (similarity: 0.954)
#   - KG Entity 4979 (similarity: 0.952)
#
# Dialogue Entity: Entity_40
# Top matches:
#   - KG Entity 40 (similarity: 1.000)
#   - KG Entity 5121 (similarity: 0.949)
#   - KG Entity 4968 (similarity: 0.949)
#
# Dialogue Entity: Entity_41
# Top matches:
#   - KG Entity 41 (similarity: 1.000)
#   - KG Entity 297 (similarity: 0.950)
#   - KG Entity 11173 (similarity: 0.949)
#
# Dialogue Entity: Entity_42
# Top matches:
#   - KG Entity 42 (similarity: 1.000)
#   - KG Entity 3769 (similarity: 0.951)
#   - KG Entity 4979 (similarity: 0.950)
#
# Dialogue Entity: Entity_43
# Top matches:
#   - KG Entity 43 (similarity: 1.000)
#   - KG Entity 4308 (similarity: 0.950)
#   - KG Entity 1416 (similarity: 0.948)
#
# Dialogue Entity: Entity_44
# Top matches:
#   - KG Entity 10442 (similarity: 0.952)
#   - KG Entity 2532 (similarity: 0.952)
#   - KG Entity 7569 (similarity: 0.952)
#
# Dialogue Entity: Entity_45
# Top matches:
#   - KG Entity 7089 (similarity: 0.948)
#   - KG Entity 7064 (similarity: 0.948)
#   - KG Entity 45 (similarity: 0.947)
#
# Dialogue Entity: Entity_46
# Top matches:
#   - KG Entity 46 (similarity: 1.000)
#   - KG Entity 11642 (similarity: 0.950)
#   - KG Entity 3588 (similarity: 0.949)
#
# Dialogue Entity: Entity_47
# Top matches:
#   - KG Entity 47 (similarity: 0.972)
#   - KG Entity 10442 (similarity: 0.952)
#   - KG Entity 596 (similarity: 0.952)
#
# Dialogue Entity: Entity_48
# Top matches:
#   - KG Entity 48 (similarity: 0.983)
#   - KG Entity 4681 (similarity: 0.950)
#   - KG Entity 5455 (similarity: 0.949)
#
# Dialogue Entity: Entity_49
# Top matches:
#   - KG Entity 49 (similarity: 0.973)
#   - KG Entity 7634 (similarity: 0.949)
#   - KG Entity 1358 (similarity: 0.949)
#
# Dialogue Entity: Entity_50
# Top matches:
#   - KG Entity 50 (similarity: 0.998)
#   - KG Entity 1563 (similarity: 0.950)
#   - KG Entity 6394 (similarity: 0.949)
#
# Dialogue Entity: Entity_51
# Top matches:
#   - KG Entity 51 (similarity: 0.974)
#   - KG Entity 10956 (similarity: 0.949)
#   - KG Entity 578 (similarity: 0.948)
#
# Dialogue Entity: Entity_52
# Top matches:
#   - KG Entity 52 (similarity: 1.000)
#   - KG Entity 8554 (similarity: 0.955)
#   - KG Entity 11543 (similarity: 0.954)
#
# Dialogue Entity: Entity_53
# Top matches:
#   - KG Entity 53 (similarity: 0.993)
#   - KG Entity 9769 (similarity: 0.955)
#   - KG Entity 9269 (similarity: 0.952)
#
# Dialogue Entity: Entity_54
# Top matches:
#   - KG Entity 54 (similarity: 0.983)
#   - KG Entity 6197 (similarity: 0.948)
#   - KG Entity 3574 (similarity: 0.948)
#
# Dialogue Entity: Entity_55
# Top matches:
#   - KG Entity 55 (similarity: 0.997)
#   - KG Entity 4356 (similarity: 0.953)
#   - KG Entity 4918 (similarity: 0.951)
#
# Dialogue Entity: Entity_56
# Top matches:
#   - KG Entity 56 (similarity: 0.996)
#   - KG Entity 3644 (similarity: 0.949)
#   - KG Entity 5481 (similarity: 0.948)
#
# Dialogue Entity: Entity_57
# Top matches:
#   - KG Entity 57 (similarity: 1.000)
#   - KG Entity 8993 (similarity: 0.950)
#   - KG Entity 8789 (similarity: 0.949)
#
# Dialogue Entity: Entity_58
# Top matches:
#   - KG Entity 58 (similarity: 1.000)
#   - KG Entity 9827 (similarity: 0.948)
#   - KG Entity 8790 (similarity: 0.948)
#
# Dialogue Entity: Entity_59
# Top matches:
#   - KG Entity 59 (similarity: 1.000)
#   - KG Entity 1717 (similarity: 0.949)
#   - KG Entity 9648 (similarity: 0.947)
#
# Dialogue Entity: Entity_60
# Top matches:
#   - KG Entity 60 (similarity: 0.999)
#   - KG Entity 7361 (similarity: 0.948)
#   - KG Entity 6049 (similarity: 0.948)
#
# Dialogue Entity: Entity_61
# Top matches:
#   - KG Entity 8085 (similarity: 0.953)
#   - KG Entity 3679 (similarity: 0.947)
#   - KG Entity 10124 (similarity: 0.947)
#
# Dialogue Entity: Entity_62
# Top matches:
#   - KG Entity 62 (similarity: 0.966)
#   - KG Entity 3961 (similarity: 0.950)
#   - KG Entity 9024 (similarity: 0.950)
#
# Dialogue Entity: Entity_63
# Top matches:
#   - KG Entity 63 (similarity: 0.970)
#   - KG Entity 4102 (similarity: 0.950)
#   - KG Entity 299 (similarity: 0.950)
#
# Dialogue Entity: Entity_64
# Top matches:
#   - KG Entity 64 (similarity: 0.982)
#   - KG Entity 7140 (similarity: 0.953)
#   - KG Entity 7991 (similarity: 0.951)
#
# Dialogue Entity: Entity_65
# Top matches:
#   - KG Entity 65 (similarity: 0.997)
#   - KG Entity 4037 (similarity: 0.952)
#   - KG Entity 8912 (similarity: 0.951)
#
# Dialogue Entity: Entity_66
# Top matches:
#   - KG Entity 66 (similarity: 0.989)
#   - KG Entity 9759 (similarity: 0.956)
#   - KG Entity 7578 (similarity: 0.950)
#
# Dialogue Entity: Entity_67
# Top matches:
#   - KG Entity 67 (similarity: 0.978)
#   - KG Entity 8221 (similarity: 0.947)
#   - KG Entity 10877 (similarity: 0.947)
#
# Dialogue Entity: Entity_68
# Top matches:
#   - KG Entity 68 (similarity: 0.994)
#   - KG Entity 9980 (similarity: 0.948)
#   - KG Entity 3176 (similarity: 0.947)
#
# Dialogue Entity: Entity_69
# Top matches:
#   - KG Entity 69 (similarity: 0.984)
#   - KG Entity 8145 (similarity: 0.950)
#   - KG Entity 6900 (similarity: 0.950)
#
# Dialogue Entity: Entity_70
# Top matches:
#   - KG Entity 70 (similarity: 0.984)
#   - KG Entity 2277 (similarity: 0.945)
#   - KG Entity 3017 (similarity: 0.945)
#
# Dialogue Entity: Entity_71
# Top matches:
#   - KG Entity 71 (similarity: 1.000)
#   - KG Entity 724 (similarity: 0.950)
#   - KG Entity 7117 (similarity: 0.948)
#
# Dialogue Entity: Entity_72
# Top matches:
#   - KG Entity 72 (similarity: 1.000)
#   - KG Entity 7010 (similarity: 0.952)
#   - KG Entity 3707 (similarity: 0.951)
#
# Dialogue Entity: Entity_73
# Top matches:
#   - KG Entity 73 (similarity: 1.000)
#   - KG Entity 10931 (similarity: 0.950)
#   - KG Entity 4262 (similarity: 0.949)
#
# Dialogue Entity: Entity_74
# Top matches:
#   - KG Entity 74 (similarity: 0.998)
#   - KG Entity 3970 (similarity: 0.952)
#   - KG Entity 530 (similarity: 0.950)
#
# Dialogue Entity: Entity_75
# Top matches:
#   - KG Entity 75 (similarity: 0.967)
#   - KG Entity 8051 (similarity: 0.949)
#   - KG Entity 9861 (similarity: 0.948)
#
# Dialogue Entity: Entity_76
# Top matches:
#   - KG Entity 76 (similarity: 0.969)
#   - KG Entity 11659 (similarity: 0.952)
#   - KG Entity 10872 (similarity: 0.951)
#
# Dialogue Entity: Entity_77
# Top matches:
#   - KG Entity 77 (similarity: 1.000)
#   - KG Entity 10718 (similarity: 0.955)
#   - KG Entity 10183 (similarity: 0.952)
#
# Dialogue Entity: Entity_78
# Top matches:
#   - KG Entity 78 (similarity: 0.960)
#   - KG Entity 2672 (similarity: 0.955)
#   - KG Entity 7570 (similarity: 0.954)
#
# Dialogue Entity: Entity_79
# Top matches:
#   - KG Entity 79 (similarity: 0.974)
#   - KG Entity 2666 (similarity: 0.950)
#   - KG Entity 7502 (similarity: 0.950)
#
# Dialogue Entity: Entity_80
# Top matches:
#   - KG Entity 80 (similarity: 0.974)
#   - KG Entity 7812 (similarity: 0.955)
#   - KG Entity 6297 (similarity: 0.953)
#
# Dialogue Entity: Entity_81
# Top matches:
#   - KG Entity 81 (similarity: 0.962)
#   - KG Entity 7048 (similarity: 0.950)
#   - KG Entity 124 (similarity: 0.949)
#
# Dialogue Entity: Entity_82
# Top matches:
#   - KG Entity 9181 (similarity: 0.948)
#   - KG Entity 6694 (similarity: 0.948)
#   - KG Entity 9420 (similarity: 0.947)
#
# Dialogue Entity: Entity_83
# Top matches:
#   - KG Entity 83 (similarity: 0.999)
#   - KG Entity 9447 (similarity: 0.948)
#   - KG Entity 10900 (similarity: 0.947)
#
# Dialogue Entity: Entity_84
# Top matches:
#   - KG Entity 84 (similarity: 0.960)
#   - KG Entity 4979 (similarity: 0.955)
#   - KG Entity 4681 (similarity: 0.953)
#
# Dialogue Entity: Entity_85
# Top matches:
#   - KG Entity 85 (similarity: 0.973)
#   - KG Entity 7427 (similarity: 0.949)
#   - KG Entity 9769 (similarity: 0.947)
#
# Dialogue Entity: Entity_86
# Top matches:
#   - KG Entity 86 (similarity: 0.955)
#   - KG Entity 4979 (similarity: 0.953)
#   - KG Entity 5741 (similarity: 0.951)
#
# Dialogue Entity: Entity_87
# Top matches:
#   - KG Entity 2032 (similarity: 0.951)
#   - KG Entity 9707 (similarity: 0.951)
#   - KG Entity 7858 (similarity: 0.951)
#
# Dialogue Entity: Entity_88
# Top matches:
#   - KG Entity 88 (similarity: 0.991)
#   - KG Entity 3614 (similarity: 0.951)
#   - KG Entity 10781 (similarity: 0.951)
#
# Dialogue Entity: Entity_89
# Top matches:
#   - KG Entity 89 (similarity: 1.000)
#   - KG Entity 5430 (similarity: 0.952)
#   - KG Entity 4918 (similarity: 0.952)
#
# Dialogue Entity: Entity_90
# Top matches:
#   - KG Entity 90 (similarity: 1.000)
#   - KG Entity 4211 (similarity: 0.950)
#   - KG Entity 4979 (similarity: 0.948)
#
# Dialogue Entity: Entity_91
# Top matches:
#   - KG Entity 91 (similarity: 1.000)
#   - KG Entity 9301 (similarity: 0.952)
#   - KG Entity 1324 (similarity: 0.951)
#
# Dialogue Entity: Entity_92
# Top matches:
#   - KG Entity 92 (similarity: 1.000)
#   - KG Entity 6954 (similarity: 0.950)
#   - KG Entity 8499 (similarity: 0.949)
#
# Dialogue Entity: Entity_93
# Top matches:
#   - KG Entity 93 (similarity: 0.995)
#   - KG Entity 9269 (similarity: 0.953)
#   - KG Entity 9839 (similarity: 0.950)
#
# Dialogue Entity: Entity_94
# Top matches:
#   - KG Entity 94 (similarity: 0.971)
#   - KG Entity 8972 (similarity: 0.951)
#   - KG Entity 8007 (similarity: 0.949)
#
# Dialogue Entity: Entity_95
# Top matches:
#   - KG Entity 95 (similarity: 0.991)
#   - KG Entity 7892 (similarity: 0.948)
#   - KG Entity 8294 (similarity: 0.948)
#
# Dialogue Entity: Entity_96
# Top matches:
#   - KG Entity 96 (similarity: 0.991)
#   - KG Entity 3764 (similarity: 0.946)
#   - KG Entity 5971 (similarity: 0.945)
#
# Dialogue Entity: Entity_97
# Top matches:
#   - KG Entity 97 (similarity: 0.991)
#   - KG Entity 9496 (similarity: 0.949)
#   - KG Entity 4918 (similarity: 0.949)
#
# Dialogue Entity: Entity_98
# Top matches:
#   - KG Entity 98 (similarity: 0.970)
#   - KG Entity 7328 (similarity: 0.951)
#   - KG Entity 7745 (similarity: 0.949)
#
# Dialogue Entity: Entity_99
# Top matches:
#   - KG Entity 6077 (similarity: 0.951)
#   - KG Entity 8706 (similarity: 0.950)
#   - KG Entity 6802 (similarity: 0.950)
#
# Dialogue Entity: Entity_100
# Top matches:
#   - KG Entity 100 (similarity: 0.984)
#   - KG Entity 8177 (similarity: 0.949)
#   - KG Entity 3760 (similarity: 0.949)
#
# Dialogue Entity: Entity_101
# Top matches:
#   - KG Entity 7328 (similarity: 0.948)
#   - KG Entity 8496 (similarity: 0.948)
#   - KG Entity 8705 (similarity: 0.947)
#
# Dialogue Entity: Entity_102
# Top matches:
#   - KG Entity 102 (similarity: 0.956)
#   - KG Entity 5692 (similarity: 0.948)
#   - KG Entity 9654 (similarity: 0.946)
#
# Dialogue Entity: Entity_103
# Top matches:
#   - KG Entity 103 (similarity: 0.994)
#   - KG Entity 6647 (similarity: 0.947)
#   - KG Entity 2724 (similarity: 0.946)
#
# Dialogue Entity: Entity_104
# Top matches:
#   - KG Entity 104 (similarity: 0.967)
#   - KG Entity 5121 (similarity: 0.951)
#   - KG Entity 8654 (similarity: 0.951)
#
# Dialogue Entity: Entity_105
# Top matches:
#   - KG Entity 105 (similarity: 0.983)
#   - KG Entity 7886 (similarity: 0.950)
#   - KG Entity 9531 (similarity: 0.948)
#
# Dialogue Entity: Entity_106
# Top matches:
#   - KG Entity 7605 (similarity: 0.950)
#   - KG Entity 9708 (similarity: 0.949)
#   - KG Entity 106 (similarity: 0.948)
#
# Dialogue Entity: Entity_107
# Top matches:
#   - KG Entity 107 (similarity: 0.991)
#   - KG Entity 9769 (similarity: 0.949)
#   - KG Entity 4313 (similarity: 0.949)
#
# Dialogue Entity: Entity_108
# Top matches:
#   - KG Entity 108 (similarity: 0.981)
#   - KG Entity 3366 (similarity: 0.951)
#   - KG Entity 6106 (similarity: 0.951)
#
# Dialogue Entity: Entity_109
# Top matches:
#   - KG Entity 109 (similarity: 0.980)
#   - KG Entity 1722 (similarity: 0.949)
#   - KG Entity 5780 (similarity: 0.949)
#
# Dialogue Entity: Entity_110
# Top matches:
#   - KG Entity 110 (similarity: 1.000)
#   - KG Entity 8252 (similarity: 0.953)
#   - KG Entity 5569 (similarity: 0.952)
#
# Dialogue Entity: Entity_111
# Top matches:
#   - KG Entity 111 (similarity: 1.000)
#   - KG Entity 11603 (similarity: 0.948)
#   - KG Entity 5485 (similarity: 0.948)
#
# Dialogue Entity: Entity_112
# Top matches:
#   - KG Entity 6279 (similarity: 0.953)
#   - KG Entity 7124 (similarity: 0.950)
#   - KG Entity 10604 (similarity: 0.947)
#
# Dialogue Entity: Entity_113
# Top matches:
#   - KG Entity 113 (similarity: 0.978)
#   - KG Entity 5169 (similarity: 0.953)
#   - KG Entity 5798 (similarity: 0.950)
#
# Dialogue Entity: Entity_114
# Top matches:
#   - KG Entity 114 (similarity: 0.954)
#   - KG Entity 3951 (similarity: 0.951)
#   - KG Entity 8988 (similarity: 0.950)
#
# Dialogue Entity: Entity_115
# Top matches:
#   - KG Entity 115 (similarity: 0.961)
#   - KG Entity 11826 (similarity: 0.949)
#   - KG Entity 7748 (similarity: 0.948)
#
# Dialogue Entity: Entity_116
# Top matches:
#   - KG Entity 116 (similarity: 0.960)
#   - KG Entity 9148 (similarity: 0.957)
#   - KG Entity 9207 (similarity: 0.953)
#
# Dialogue Entity: Entity_117
# Top matches:
#   - KG Entity 117 (similarity: 0.968)
#   - KG Entity 7993 (similarity: 0.951)
#   - KG Entity 6292 (similarity: 0.949)
#
# Dialogue Entity: Entity_118
# Top matches:
#   - KG Entity 118 (similarity: 0.990)
#   - KG Entity 1317 (similarity: 0.950)
#   - KG Entity 9195 (similarity: 0.950)
#
# Dialogue Entity: Entity_119
# Top matches:
#   - KG Entity 119 (similarity: 0.994)
#   - KG Entity 3065 (similarity: 0.945)
#   - KG Entity 8124 (similarity: 0.944)
#
# Dialogue Entity: Entity_120
# Top matches:
#   - KG Entity 120 (similarity: 0.998)
#   - KG Entity 4047 (similarity: 0.952)
#   - KG Entity 2793 (similarity: 0.950)
#
# Dialogue Entity: Entity_121
# Top matches:
#   - KG Entity 121 (similarity: 0.987)
#   - KG Entity 8676 (similarity: 0.953)
#   - KG Entity 5971 (similarity: 0.953)
#
# Dialogue Entity: Entity_122
# Top matches:
#   - KG Entity 122 (similarity: 1.000)
#   - KG Entity 10512 (similarity: 0.946)
#   - KG Entity 6170 (similarity: 0.945)
#
# Dialogue Entity: Entity_123
# Top matches:
#   - KG Entity 123 (similarity: 1.000)
#   - KG Entity 5429 (similarity: 0.948)
#   - KG Entity 11600 (similarity: 0.947)
#
# Dialogue Entity: Entity_124
# Top matches:
#   - KG Entity 124 (similarity: 1.000)
#   - KG Entity 9229 (similarity: 0.953)
#   - KG Entity 10765 (similarity: 0.952)
#
# Dialogue Entity: Entity_125
# Top matches:
#   - KG Entity 125 (similarity: 1.000)
#   - KG Entity 11733 (similarity: 0.950)
#   - KG Entity 9986 (similarity: 0.949)
#
# Dialogue Entity: Entity_126
# Top matches:
#   - KG Entity 126 (similarity: 1.000)
#   - KG Entity 6900 (similarity: 0.952)
#   - KG Entity 2722 (similarity: 0.951)
#
# Dialogue Entity: Entity_127
# Top matches:
#   - KG Entity 3657 (similarity: 0.952)
#   - KG Entity 4158 (similarity: 0.948)
#   - KG Entity 803 (similarity: 0.948)
#
# Dialogue Entity: Entity_128
# Top matches:
#   - KG Entity 128 (similarity: 0.959)
#   - KG Entity 6785 (similarity: 0.949)
#   - KG Entity 3588 (similarity: 0.948)
#
# Dialogue Entity: Entity_129
# Top matches:
#   - KG Entity 129 (similarity: 0.970)
#   - KG Entity 5503 (similarity: 0.952)
#   - KG Entity 5355 (similarity: 0.951)
#
# Dialogue Entity: Entity_130
# Top matches:
#   - KG Entity 130 (similarity: 0.983)
#   - KG Entity 10144 (similarity: 0.956)
#   - KG Entity 4264 (similarity: 0.950)
#
# Dialogue Entity: Entity_131
# Top matches:
#   - KG Entity 131 (similarity: 0.972)
#   - KG Entity 10036 (similarity: 0.953)
#   - KG Entity 7086 (similarity: 0.952)
#
# Dialogue Entity: Entity_132
# Top matches:
#   - KG Entity 132 (similarity: 0.999)
#   - KG Entity 8309 (similarity: 0.949)
#   - KG Entity 5512 (similarity: 0.948)
#
# Dialogue Entity: Entity_133
# Top matches:
#   - KG Entity 133 (similarity: 0.980)
#   - KG Entity 3764 (similarity: 0.954)
#   - KG Entity 5625 (similarity: 0.952)
#
# Dialogue Entity: Entity_134
# Top matches:
#   - KG Entity 134 (similarity: 0.965)
#   - KG Entity 8016 (similarity: 0.956)
#   - KG Entity 4203 (similarity: 0.951)
#
# Dialogue Entity: Entity_135
# Top matches:
#   - KG Entity 135 (similarity: 0.972)
#   - KG Entity 6396 (similarity: 0.954)
#   - KG Entity 4294 (similarity: 0.954)
#
# Dialogue Entity: Entity_136
# Top matches:
#   - KG Entity 10064 (similarity: 0.952)
#   - KG Entity 1690 (similarity: 0.948)
#   - KG Entity 9648 (similarity: 0.948)
#
# Dialogue Entity: Entity_137
# Top matches:
#   - KG Entity 137 (similarity: 0.971)
#   - KG Entity 6977 (similarity: 0.954)
#   - KG Entity 3597 (similarity: 0.951)
#
# Dialogue Entity: Entity_138
# Top matches:
#   - KG Entity 138 (similarity: 1.000)
#   - KG Entity 4500 (similarity: 0.948)
#   - KG Entity 8351 (similarity: 0.947)
#
# Dialogue Entity: Entity_139
# Top matches:
#   - KG Entity 139 (similarity: 1.000)
#   - KG Entity 10839 (similarity: 0.952)
#   - KG Entity 3840 (similarity: 0.951)
#
# Dialogue Entity: Entity_140
# Top matches:
#   - KG Entity 140 (similarity: 1.000)
#   - KG Entity 11480 (similarity: 0.954)
#   - KG Entity 2805 (similarity: 0.952)
#
# Dialogue Entity: Entity_141
# Top matches:
#   - KG Entity 141 (similarity: 1.000)
#   - KG Entity 10883 (similarity: 0.954)
#   - KG Entity 9707 (similarity: 0.950)
#
# Dialogue Entity: Entity_142
# Top matches:
#   - KG Entity 142 (similarity: 1.000)
#   - KG Entity 991 (similarity: 0.952)
#   - KG Entity 7031 (similarity: 0.951)
#
# Dialogue Entity: Entity_143
# Top matches:
#   - KG Entity 143 (similarity: 1.000)
#   - KG Entity 10176 (similarity: 0.950)
#   - KG Entity 3487 (similarity: 0.946)
#
# Dialogue Entity: Entity_144
# Top matches:
#   - KG Entity 144 (similarity: 1.000)
#   - KG Entity 4979 (similarity: 0.953)
#   - KG Entity 3399 (similarity: 0.952)
#
# Dialogue Entity: Entity_145
# Top matches:
#   - KG Entity 145 (similarity: 1.000)
#   - KG Entity 2571 (similarity: 0.950)
#   - KG Entity 11788 (similarity: 0.949)
#
# Dialogue Entity: Entity_146
# Top matches:
#   - KG Entity 146 (similarity: 1.000)
#   - KG Entity 11327 (similarity: 0.951)
#   - KG Entity 10512 (similarity: 0.950)
#
# Dialogue Entity: Entity_147
# Top matches:
#   - KG Entity 147 (similarity: 0.999)
#   - KG Entity 5938 (similarity: 0.945)
#   - KG Entity 3408 (similarity: 0.945)
#
# Dialogue Entity: Entity_148
# Top matches:
#   - KG Entity 148 (similarity: 0.982)
#   - KG Entity 9419 (similarity: 0.952)
#   - KG Entity 10916 (similarity: 0.951)
#
# Dialogue Entity: Entity_149
# Top matches:
#   - KG Entity 149 (similarity: 0.973)
#   - KG Entity 8141 (similarity: 0.954)
#   - KG Entity 3334 (similarity: 0.952)
#
# Dialogue Entity: Entity_150
# Top matches:
#   - KG Entity 150 (similarity: 0.973)
#   - KG Entity 2495 (similarity: 0.952)
#   - KG Entity 5503 (similarity: 0.952)
#
# Dialogue Entity: Entity_151
# Top matches:
#   - KG Entity 151 (similarity: 0.957)
#   - KG Entity 10891 (similarity: 0.952)
#   - KG Entity 8871 (similarity: 0.952)
#
# Dialogue Entity: Entity_152
# Top matches:
#   - KG Entity 152 (similarity: 0.970)
#   - KG Entity 10835 (similarity: 0.949)
#   - KG Entity 5784 (similarity: 0.946)
#
# Dialogue Entity: Entity_153
# Top matches:
#   - KG Entity 153 (similarity: 0.992)
#   - KG Entity 9226 (similarity: 0.947)
#   - KG Entity 5052 (similarity: 0.947)
#
# Dialogue Entity: Entity_154
# Top matches:
#   - KG Entity 154 (similarity: 0.970)
#   - KG Entity 4119 (similarity: 0.949)
#   - KG Entity 9456 (similarity: 0.948)
#
# Dialogue Entity: Entity_155
# Top matches:
#   - KG Entity 1519 (similarity: 0.951)
#   - KG Entity 11703 (similarity: 0.950)
#   - KG Entity 8499 (similarity: 0.949)
#
# Dialogue Entity: Entity_156
# Top matches:
#   - KG Entity 156 (similarity: 0.976)
#   - KG Entity 6620 (similarity: 0.954)
#   - KG Entity 10442 (similarity: 0.953)
#
# Dialogue Entity: Entity_157
# Top matches:
#   - KG Entity 157 (similarity: 0.988)
#   - KG Entity 6275 (similarity: 0.944)
#   - KG Entity 3404 (similarity: 0.943)
#
# Dialogue Entity: Entity_158
# Top matches:
#   - KG Entity 1716 (similarity: 0.952)
#   - KG Entity 4429 (similarity: 0.952)
#   - KG Entity 11013 (similarity: 0.952)
#
# Dialogue Entity: Entity_159
# Top matches:
#   - KG Entity 159 (similarity: 0.999)
#   - KG Entity 9361 (similarity: 0.952)
#   - KG Entity 8739 (similarity: 0.951)
#
# Dialogue Entity: Entity_160
# Top matches:
#   - KG Entity 160 (similarity: 0.956)
#   - KG Entity 7858 (similarity: 0.949)
#   - KG Entity 5455 (similarity: 0.949)
#
# Dialogue Entity: Entity_161
# Top matches:
#   - KG Entity 161 (similarity: 0.994)
#   - KG Entity 4447 (similarity: 0.949)
#   - KG Entity 7692 (similarity: 0.949)
#
# Dialogue Entity: Entity_162
# Top matches:
#   - KG Entity 162 (similarity: 0.968)
#   - KG Entity 9654 (similarity: 0.949)
#   - KG Entity 6086 (similarity: 0.948)
#
# Dialogue Entity: Entity_163
# Top matches:
#   - KG Entity 163 (similarity: 0.977)
#   - KG Entity 8867 (similarity: 0.953)
#   - KG Entity 6424 (similarity: 0.952)
#
# Dialogue Entity: Entity_164
# Top matches:
#   - KG Entity 164 (similarity: 0.960)
#   - KG Entity 9269 (similarity: 0.951)
#   - KG Entity 3571 (similarity: 0.949)
#
# Dialogue Entity: Entity_165
# Top matches:
#   - KG Entity 165 (similarity: 0.957)
#   - KG Entity 11433 (similarity: 0.955)
#   - KG Entity 3278 (similarity: 0.955)
#
# Dialogue Entity: Entity_166
# Top matches:
#   - KG Entity 166 (similarity: 0.978)
#   - KG Entity 7502 (similarity: 0.949)
#   - KG Entity 10299 (similarity: 0.948)
#
# Dialogue Entity: Entity_167
# Top matches:
#   - KG Entity 4186 (similarity: 0.952)
#   - KG Entity 167 (similarity: 0.951)
#   - KG Entity 3842 (similarity: 0.950)
#
# Dialogue Entity: Entity_168
# Top matches:
#   - KG Entity 168 (similarity: 0.965)
#   - KG Entity 7203 (similarity: 0.951)
#   - KG Entity 8489 (similarity: 0.951)
#
# Dialogue Entity: Entity_169
# Top matches:
#   - KG Entity 4847 (similarity: 0.949)
#   - KG Entity 6381 (similarity: 0.948)
#   - KG Entity 8139 (similarity: 0.947)
#
# Dialogue Entity: Entity_170
# Top matches:
#   - KG Entity 170 (similarity: 0.984)
#   - KG Entity 4532 (similarity: 0.950)
#   - KG Entity 3878 (similarity: 0.949)
#
# Dialogue Entity: Entity_171
# Top matches:
#   - KG Entity 171 (similarity: 0.955)
#   - KG Entity 8565 (similarity: 0.946)
#   - KG Entity 1714 (similarity: 0.946)
#
# Dialogue Entity: Entity_172
# Top matches:
#   - KG Entity 10108 (similarity: 0.951)
#   - KG Entity 5725 (similarity: 0.950)
#   - KG Entity 10201 (similarity: 0.949)
#
# Dialogue Entity: Entity_173
# Top matches:
#   - KG Entity 173 (similarity: 0.963)
#   - KG Entity 4219 (similarity: 0.951)
#   - KG Entity 2104 (similarity: 0.950)
#
# Dialogue Entity: Entity_174
# Top matches:
#   - KG Entity 174 (similarity: 0.974)
#   - KG Entity 6290 (similarity: 0.953)
#   - KG Entity 9269 (similarity: 0.951)
#
# Dialogue Entity: Entity_175
# Top matches:
#   - KG Entity 175 (similarity: 0.958)
#   - KG Entity 3065 (similarity: 0.951)
#   - KG Entity 1939 (similarity: 0.951)
#
# Dialogue Entity: Entity_176
# Top matches:
#   - KG Entity 176 (similarity: 1.000)
#   - KG Entity 7857 (similarity: 0.952)
#   - KG Entity 5504 (similarity: 0.951)
#
# Dialogue Entity: Entity_177
# Top matches:
#   - KG Entity 177 (similarity: 1.000)
#   - KG Entity 5563 (similarity: 0.949)
#   - KG Entity 7748 (similarity: 0.945)
#
# Dialogue Entity: Entity_178
# Top matches:
#   - KG Entity 178 (similarity: 1.000)
#   - KG Entity 8678 (similarity: 0.956)
#   - KG Entity 10824 (similarity: 0.951)
#
# Dialogue Entity: Entity_179
# Top matches:
#   - KG Entity 179 (similarity: 1.000)
#   - KG Entity 4012 (similarity: 0.949)
#   - KG Entity 7302 (similarity: 0.949)
#
# Dialogue Entity: Entity_180
# Top matches:
#   - KG Entity 180 (similarity: 0.978)
#   - KG Entity 948 (similarity: 0.950)
#   - KG Entity 9769 (similarity: 0.950)
#
# Dialogue Entity: Entity_181
# Top matches:
#   - KG Entity 7172 (similarity: 0.951)
#   - KG Entity 7360 (similarity: 0.947)
#   - KG Entity 9898 (similarity: 0.947)
#
# Dialogue Entity: Entity_182
# Top matches:
#   - KG Entity 8353 (similarity: 0.952)
#   - KG Entity 3433 (similarity: 0.951)
#   - KG Entity 1204 (similarity: 0.949)
#
# Dialogue Entity: Entity_183
# Top matches:
#   - KG Entity 183 (similarity: 1.000)
#   - KG Entity 6926 (similarity: 0.950)
#   - KG Entity 557 (similarity: 0.948)
#
# Dialogue Entity: Entity_184
# Top matches:
#   - KG Entity 3645 (similarity: 0.952)
#   - KG Entity 2090 (similarity: 0.951)
#   - KG Entity 11548 (similarity: 0.950)
#
# Dialogue Entity: Entity_185
# Top matches:
#   - KG Entity 1677 (similarity: 0.948)
#   - KG Entity 185 (similarity: 0.948)
#   - KG Entity 8871 (similarity: 0.947)
#
# Dialogue Entity: Entity_186
# Top matches:
#   - KG Entity 186 (similarity: 0.961)
#   - KG Entity 4314 (similarity: 0.951)
#   - KG Entity 10982 (similarity: 0.950)
#
# Dialogue Entity: Entity_187
# Top matches:
#   - KG Entity 187 (similarity: 0.982)
#   - KG Entity 5170 (similarity: 0.952)
#   - KG Entity 7311 (similarity: 0.950)
#
# Dialogue Entity: Entity_188
# Top matches:
#   - KG Entity 188 (similarity: 1.000)
#   - KG Entity 8452 (similarity: 0.948)
#   - KG Entity 2032 (similarity: 0.948)
#
# Dialogue Entity: Entity_189
# Top matches:
#   - KG Entity 189 (similarity: 0.975)
#   - KG Entity 10436 (similarity: 0.950)
#   - KG Entity 10683 (similarity: 0.950)
#
# Dialogue Entity: Entity_190
# Top matches:
#   - KG Entity 190 (similarity: 0.962)
#   - KG Entity 8790 (similarity: 0.957)
#   - KG Entity 11446 (similarity: 0.950)
#
# Dialogue Entity: Entity_191
# Top matches:
#   - KG Entity 191 (similarity: 0.968)
#   - KG Entity 11421 (similarity: 0.948)
#   - KG Entity 1716 (similarity: 0.947)
#
# Dialogue Entity: Entity_192
# Top matches:
#   - KG Entity 192 (similarity: 0.974)
#   - KG Entity 9741 (similarity: 0.955)
#   - KG Entity 810 (similarity: 0.952)
#
# Dialogue Entity: Entity_193
# Top matches:
#   - KG Entity 9967 (similarity: 0.955)
#   - KG Entity 8382 (similarity: 0.953)
#   - KG Entity 6435 (similarity: 0.953)
#
# Dialogue Entity: Entity_194
# Top matches:
#   - KG Entity 194 (similarity: 0.966)
#   - KG Entity 9749 (similarity: 0.952)
#   - KG Entity 11789 (similarity: 0.951)
#
# Dialogue Entity: Entity_195
# Top matches:
#   - KG Entity 195 (similarity: 0.960)
#   - KG Entity 8497 (similarity: 0.949)
#   - KG Entity 7686 (similarity: 0.949)
#
# Dialogue Entity: Entity_196
# Top matches:
#   - KG Entity 196 (similarity: 1.000)
#   - KG Entity 4051 (similarity: 0.945)
#   - KG Entity 9974 (similarity: 0.945)
#
# Dialogue Entity: Entity_197
# Top matches:
#   - KG Entity 197 (similarity: 0.961)
#   - KG Entity 6106 (similarity: 0.960)
#   - KG Entity 5916 (similarity: 0.956)
#
# Dialogue Entity: Entity_198
# Top matches:
#   - KG Entity 198 (similarity: 0.991)
#   - KG Entity 9910 (similarity: 0.950)
#   - KG Entity 691 (similarity: 0.950)
#
# Dialogue Entity: Entity_199
# Top matches:
#   - KG Entity 199 (similarity: 1.000)
#   - KG Entity 8658 (similarity: 0.951)
#   - KG Entity 1716 (similarity: 0.950)
#
# Dialogue Entity: Entity_200
# Top matches:
#   - KG Entity 200 (similarity: 1.000)
#   - KG Entity 4370 (similarity: 0.953)
#   - KG Entity 8871 (similarity: 0.953)
#
# Dialogue Entity: Entity_201
# Top matches:
#   - KG Entity 950 (similarity: 0.945)
#   - KG Entity 10108 (similarity: 0.944)
#   - KG Entity 6813 (similarity: 0.944)
#
# Dialogue Entity: Entity_202
# Top matches:
#   - KG Entity 202 (similarity: 0.967)
#   - KG Entity 1719 (similarity: 0.952)
#   - KG Entity 1293 (similarity: 0.952)
#
# Dialogue Entity: Entity_203
# Top matches:
#   - KG Entity 203 (similarity: 0.971)
#   - KG Entity 3482 (similarity: 0.951)
#   - KG Entity 7126 (similarity: 0.951)
#
# Dialogue Entity: Entity_204
# Top matches:
#   - KG Entity 204 (similarity: 0.960)
#   - KG Entity 10442 (similarity: 0.951)
#   - KG Entity 7426 (similarity: 0.950)
#
# Dialogue Entity: Entity_205
# Top matches:
#   - KG Entity 205 (similarity: 0.980)
#   - KG Entity 2457 (similarity: 0.949)
#   - KG Entity 5995 (similarity: 0.948)
#
# Dialogue Entity: Entity_206
# Top matches:
#   - KG Entity 206 (similarity: 1.000)
#   - KG Entity 2048 (similarity: 0.950)
#   - KG Entity 8932 (similarity: 0.950)
#
# Dialogue Entity: Entity_207
# Top matches:
#   - KG Entity 207 (similarity: 1.000)
#   - KG Entity 6410 (similarity: 0.949)
#   - KG Entity 8258 (similarity: 0.949)
#
# Dialogue Entity: Entity_208
# Top matches:
#   - KG Entity 208 (similarity: 1.000)
#   - KG Entity 2272 (similarity: 0.943)
#   - KG Entity 3065 (similarity: 0.942)
#
# Dialogue Entity: Entity_209
# Top matches:
#   - KG Entity 209 (similarity: 0.992)
#   - KG Entity 9269 (similarity: 0.952)
#   - KG Entity 10653 (similarity: 0.952)
#
# Dialogue Entity: Entity_210
# Top matches:
#   - KG Entity 210 (similarity: 0.964)
#   - KG Entity 3407 (similarity: 0.953)
#   - KG Entity 8201 (similarity: 0.952)
#
# Dialogue Entity: Entity_211
# Top matches:
#   - KG Entity 2685 (similarity: 0.951)
#   - KG Entity 10134 (similarity: 0.951)
#   - KG Entity 3571 (similarity: 0.951)
#
# Dialogue Entity: Entity_212
# Top matches:
#   - KG Entity 11066 (similarity: 0.953)
#   - KG Entity 738 (similarity: 0.951)
#   - KG Entity 212 (similarity: 0.948)
#
# Dialogue Entity: Entity_213
# Top matches:
#   - KG Entity 213 (similarity: 0.974)
#   - KG Entity 7762 (similarity: 0.954)
#   - KG Entity 6376 (similarity: 0.953)
#
# Dialogue Entity: Entity_214
# Top matches:
#   - KG Entity 214 (similarity: 0.960)
#   - KG Entity 420 (similarity: 0.951)
#   - KG Entity 3597 (similarity: 0.950)
#
# Dialogue Entity: Entity_215
# Top matches:
#   - KG Entity 215 (similarity: 0.998)
#   - KG Entity 6435 (similarity: 0.953)
#   - KG Entity 8659 (similarity: 0.952)
#
# Dialogue Entity: Entity_216
# Top matches:
#   - KG Entity 216 (similarity: 1.000)
#   - KG Entity 8498 (similarity: 0.949)
#   - KG Entity 241 (similarity: 0.948)
#
# Dialogue Entity: Entity_217
# Top matches:
#   - KG Entity 217 (similarity: 1.000)
#   - KG Entity 11655 (similarity: 0.948)
#   - KG Entity 11730 (similarity: 0.947)
#
# Dialogue Entity: Entity_218
# Top matches:
#   - KG Entity 218 (similarity: 0.950)
#   - KG Entity 5062 (similarity: 0.946)
#   - KG Entity 11224 (similarity: 0.944)
#
# Dialogue Entity: Entity_219
# Top matches:
#   - KG Entity 219 (similarity: 0.958)
#   - KG Entity 2316 (similarity: 0.950)
#   - KG Entity 1212 (similarity: 0.949)
#
# Dialogue Entity: Entity_220
# Top matches:
#   - KG Entity 220 (similarity: 1.000)
#   - KG Entity 7164 (similarity: 0.947)
#   - KG Entity 4032 (similarity: 0.946)
#
# Dialogue Entity: Entity_221
# Top matches:
#   - KG Entity 221 (similarity: 0.968)
#   - KG Entity 691 (similarity: 0.949)
#   - KG Entity 9741 (similarity: 0.948)
#
# Dialogue Entity: Entity_222
# Top matches:
#   - KG Entity 222 (similarity: 0.962)
#   - KG Entity 4746 (similarity: 0.956)
#   - KG Entity 9762 (similarity: 0.954)
#
# Dialogue Entity: Entity_223
# Top matches:
#   - KG Entity 223 (similarity: 0.971)
#   - KG Entity 9129 (similarity: 0.953)
#   - KG Entity 1563 (similarity: 0.953)
#
# Dialogue Entity: Entity_224
# Top matches:
#   - KG Entity 224 (similarity: 1.000)
#   - KG Entity 11548 (similarity: 0.951)
#   - KG Entity 11809 (similarity: 0.951)
#
# Dialogue Entity: Entity_225
# Top matches:
#   - KG Entity 225 (similarity: 1.000)
#   - KG Entity 971 (similarity: 0.949)
#   - KG Entity 8678 (similarity: 0.949)
#
# Dialogue Entity: Entity_226
# Top matches:
#   - KG Entity 226 (similarity: 0.970)
#   - KG Entity 11853 (similarity: 0.945)
#   - KG Entity 73 (similarity: 0.945)
#
# Dialogue Entity: Entity_227
# Top matches:
#   - KG Entity 227 (similarity: 1.000)
#   - KG Entity 9794 (similarity: 0.949)
#   - KG Entity 858 (similarity: 0.949)
#
# Dialogue Entity: Entity_228
# Top matches:
#   - KG Entity 228 (similarity: 0.981)
#   - KG Entity 5627 (similarity: 0.947)
#   - KG Entity 4786 (similarity: 0.947)
#
# Dialogue Entity: Entity_229
# Top matches:
#   - KG Entity 9269 (similarity: 0.952)
#   - KG Entity 11066 (similarity: 0.951)
#   - KG Entity 11631 (similarity: 0.951)
#
# Dialogue Entity: Entity_230
# Top matches:
#   - KG Entity 230 (similarity: 0.998)
#   - KG Entity 11670 (similarity: 0.953)
#   - KG Entity 2285 (similarity: 0.952)
#
# Dialogue Entity: Entity_231
# Top matches:
#   - KG Entity 231 (similarity: 0.973)
#   - KG Entity 215 (similarity: 0.951)
#   - KG Entity 11669 (similarity: 0.951)
#
# Dialogue Entity: Entity_232
# Top matches:
#   - KG Entity 232 (similarity: 0.972)
#   - KG Entity 3065 (similarity: 0.952)
#   - KG Entity 10485 (similarity: 0.952)
#
# Dialogue Entity: Entity_233
# Top matches:
#   - KG Entity 233 (similarity: 0.977)
#   - KG Entity 9660 (similarity: 0.951)
#   - KG Entity 8510 (similarity: 0.951)
#
# Dialogue Entity: Entity_234
# Top matches:
#   - KG Entity 3970 (similarity: 0.956)
#   - KG Entity 5430 (similarity: 0.952)
#   - KG Entity 10515 (similarity: 0.950)
#
# Dialogue Entity: Entity_235
# Top matches:
#   - KG Entity 235 (similarity: 0.997)
#   - KG Entity 3278 (similarity: 0.947)
#   - KG Entity 5692 (similarity: 0.946)
#
# Dialogue Entity: Entity_236
# Top matches:
#   - KG Entity 236 (similarity: 0.959)
#   - KG Entity 9096 (similarity: 0.954)
#   - KG Entity 9420 (similarity: 0.954)
#
# Dialogue Entity: Entity_237
# Top matches:
#   - KG Entity 237 (similarity: 0.988)
#   - KG Entity 8588 (similarity: 0.952)
#   - KG Entity 2673 (similarity: 0.951)
#
# Dialogue Entity: Entity_238
# Top matches:
#   - KG Entity 238 (similarity: 0.968)
#   - KG Entity 4103 (similarity: 0.948)
#   - KG Entity 11471 (similarity: 0.947)
#
# Dialogue Entity: Entity_239
# Top matches:
#   - KG Entity 239 (similarity: 0.983)
#   - KG Entity 9769 (similarity: 0.953)
#   - KG Entity 6136 (similarity: 0.951)
#
# Dialogue Entity: Entity_240
# Top matches:
#   - KG Entity 240 (similarity: 0.950)
#   - KG Entity 10724 (similarity: 0.949)
#   - KG Entity 4699 (similarity: 0.949)
#
# Dialogue Entity: Entity_241
# Top matches:
#   - KG Entity 241 (similarity: 1.000)
#   - KG Entity 9299 (similarity: 0.954)
#   - KG Entity 11691 (similarity: 0.952)
#
# Dialogue Entity: Entity_242
# Top matches:
#   - KG Entity 242 (similarity: 0.997)
#   - KG Entity 11486 (similarity: 0.952)
#   - KG Entity 10201 (similarity: 0.952)
#
# Dialogue Entity: Entity_243
# Top matches:
#   - KG Entity 243 (similarity: 0.990)
#   - KG Entity 11066 (similarity: 0.947)
#   - KG Entity 6106 (similarity: 0.947)
#
# Dialogue Entity: Entity_244
# Top matches:
#   - KG Entity 244 (similarity: 0.999)
#   - KG Entity 7056 (similarity: 0.948)
#   - KG Entity 5181 (similarity: 0.947)
#
# Dialogue Entity: Entity_245
# Top matches:
#   - KG Entity 245 (similarity: 0.976)
#   - KG Entity 7366 (similarity: 0.951)
#   - KG Entity 6297 (similarity: 0.951)
#
# Dialogue Entity: Entity_246
# Top matches:
#   - KG Entity 246 (similarity: 0.967)
#   - KG Entity 3510 (similarity: 0.951)
#   - KG Entity 4972 (similarity: 0.950)
#
# Dialogue Entity: Entity_247
# Top matches:
#   - KG Entity 247 (similarity: 0.952)
#   - KG Entity 10182 (similarity: 0.948)
#   - KG Entity 7759 (similarity: 0.946)
#
# Dialogue Entity: Entity_248
# Top matches:
#   - KG Entity 248 (similarity: 0.991)
#   - KG Entity 11071 (similarity: 0.946)
#   - KG Entity 8426 (similarity: 0.943)
#
# Dialogue Entity: Entity_249
# Top matches:
#   - KG Entity 249 (similarity: 0.987)
#   - KG Entity 11250 (similarity: 0.953)
#   - KG Entity 6633 (similarity: 0.951)
#
# Dialogue Entity: Entity_250
# Top matches:
#   - KG Entity 250 (similarity: 0.966)
#   - KG Entity 409 (similarity: 0.950)
#   - KG Entity 10378 (similarity: 0.950)
#
# Dialogue Entity: Entity_251
# Top matches:
#   - KG Entity 251 (similarity: 0.998)
#   - KG Entity 2714 (similarity: 0.955)
#   - KG Entity 948 (similarity: 0.955)
#
# Dialogue Entity: Entity_252
# Top matches:
#   - KG Entity 252 (similarity: 0.978)
#   - KG Entity 8015 (similarity: 0.948)
#   - KG Entity 5772 (similarity: 0.948)
#
# Dialogue Entity: Entity_253
# Top matches:
#   - KG Entity 1028 (similarity: 0.951)
#   - KG Entity 8314 (similarity: 0.949)
#   - KG Entity 10088 (similarity: 0.949)
#
# Dialogue Entity: Entity_254
# Top matches:
#   - KG Entity 254 (similarity: 0.985)
#   - KG Entity 9615 (similarity: 0.943)
#   - KG Entity 8101 (similarity: 0.942)
#
# Dialogue Entity: Entity_255
# Top matches:
#   - KG Entity 255 (similarity: 0.992)
#   - KG Entity 9741 (similarity: 0.951)
#   - KG Entity 10308 (similarity: 0.950)
#
# Dialogue Entity: Entity_256
# Top matches:
#   - KG Entity 256 (similarity: 0.969)
#   - KG Entity 6633 (similarity: 0.948)
#   - KG Entity 5169 (similarity: 0.948)
#
# Dialogue Entity: Entity_257
# Top matches:
#   - KG Entity 257 (similarity: 0.992)
#   - KG Entity 9297 (similarity: 0.954)
#   - KG Entity 10088 (similarity: 0.953)
#
# Dialogue Entity: Entity_258
# Top matches:
#   - KG Entity 258 (similarity: 0.999)
#   - KG Entity 4918 (similarity: 0.956)
#   - KG Entity 6633 (similarity: 0.954)
#
# Dialogue Entity: Entity_259
# Top matches:
#   - KG Entity 259 (similarity: 0.962)
#   - KG Entity 2805 (similarity: 0.952)
#   - KG Entity 7048 (similarity: 0.950)
#
# Dialogue Entity: Entity_260
# Top matches:
#   - KG Entity 260 (similarity: 0.996)
#   - KG Entity 10318 (similarity: 0.954)
#   - KG Entity 7053 (similarity: 0.952)
#
# Dialogue Entity: Entity_261
# Top matches:
#   - KG Entity 261 (similarity: 1.000)
#   - KG Entity 6104 (similarity: 0.953)
#   - KG Entity 176 (similarity: 0.949)
#
# Dialogue Entity: Entity_262
# Top matches:
#   - KG Entity 262 (similarity: 1.000)
#   - KG Entity 10188 (similarity: 0.950)
#   - KG Entity 8016 (similarity: 0.948)
#
# Dialogue Entity: Entity_263
# Top matches:
#   - KG Entity 263 (similarity: 0.958)
#   - KG Entity 9739 (similarity: 0.949)
#   - KG Entity 7830 (similarity: 0.947)
#
# Dialogue Entity: Entity_264
# Top matches:
#   - KG Entity 264 (similarity: 0.972)
#   - KG Entity 4054 (similarity: 0.952)
#   - KG Entity 10079 (similarity: 0.950)
#
# Dialogue Entity: Entity_265
# Top matches:
#   - KG Entity 265 (similarity: 0.973)
#   - KG Entity 7745 (similarity: 0.948)
#   - KG Entity 10108 (similarity: 0.948)
#
# Dialogue Entity: Entity_266
# Top matches:
#   - KG Entity 266 (similarity: 0.999)
#   - KG Entity 9333 (similarity: 0.950)
#   - KG Entity 10155 (similarity: 0.949)
#
# Dialogue Entity: Entity_267
# Top matches:
#   - KG Entity 267 (similarity: 0.999)
#   - KG Entity 6189 (similarity: 0.957)
#   - KG Entity 9207 (similarity: 0.953)
#
# Dialogue Entity: Entity_268
# Top matches:
#   - KG Entity 268 (similarity: 0.992)
#   - KG Entity 7173 (similarity: 0.952)
#   - KG Entity 683 (similarity: 0.951)
#
# Dialogue Entity: Entity_269
# Top matches:
#   - KG Entity 269 (similarity: 0.999)
#   - KG Entity 9674 (similarity: 0.947)
#   - KG Entity 3766 (similarity: 0.947)
#
# Dialogue Entity: Entity_270
# Top matches:
#   - KG Entity 270 (similarity: 0.958)
#   - KG Entity 1022 (similarity: 0.949)
#   - KG Entity 10143 (similarity: 0.949)
#
# Dialogue Entity: Entity_271
# Top matches:
#   - KG Entity 9271 (similarity: 0.950)
#   - KG Entity 6793 (similarity: 0.949)
#   - KG Entity 8128 (similarity: 0.946)
#
# Dialogue Entity: Entity_272
# Top matches:
#   - KG Entity 272 (similarity: 0.992)
#   - KG Entity 2725 (similarity: 0.951)
#   - KG Entity 4527 (similarity: 0.951)
#
# Dialogue Entity: Entity_273
# Top matches:
#   - KG Entity 273 (similarity: 1.000)
#   - KG Entity 8211 (similarity: 0.952)
#   - KG Entity 7515 (similarity: 0.952)
#
# Dialogue Entity: Entity_274
# Top matches:
#   - KG Entity 274 (similarity: 1.000)
#   - KG Entity 5430 (similarity: 0.950)
#   - KG Entity 9679 (similarity: 0.946)
#
# Dialogue Entity: Entity_275
# Top matches:
#   - KG Entity 275 (similarity: 1.000)
#   - KG Entity 9762 (similarity: 0.947)
#   - KG Entity 11733 (similarity: 0.946)
#
# Dialogue Entity: Entity_276
# Top matches:
#   - KG Entity 276 (similarity: 0.961)
#   - KG Entity 8136 (similarity: 0.950)
#   - KG Entity 10391 (similarity: 0.949)
#
# Dialogue Entity: Entity_277
# Top matches:
#   - KG Entity 277 (similarity: 0.999)
#   - KG Entity 9506 (similarity: 0.956)
#   - KG Entity 8968 (similarity: 0.946)
#
# Dialogue Entity: Entity_278
# Top matches:
#   - KG Entity 278 (similarity: 0.997)
#   - KG Entity 3276 (similarity: 0.950)
#   - KG Entity 7745 (similarity: 0.950)
#
# Dialogue Entity: Entity_279
# Top matches:
#   - KG Entity 279 (similarity: 0.955)
#   - KG Entity 7502 (similarity: 0.951)
#   - KG Entity 10183 (similarity: 0.950)
#
# Dialogue Entity: Entity_280
# Top matches:
#   - KG Entity 280 (similarity: 0.991)
#   - KG Entity 5429 (similarity: 0.951)
#   - KG Entity 3380 (similarity: 0.951)
#
# Dialogue Entity: Entity_281
# Top matches:
#   - KG Entity 281 (similarity: 0.957)
#   - KG Entity 7597 (similarity: 0.950)
#   - KG Entity 6298 (similarity: 0.949)
#
# Dialogue Entity: Entity_282
# Top matches:
#   - KG Entity 282 (similarity: 0.981)
#   - KG Entity 8792 (similarity: 0.950)
#   - KG Entity 2989 (similarity: 0.949)
#
# Dialogue Entity: Entity_283
# Top matches:
#   - KG Entity 283 (similarity: 0.997)
#   - KG Entity 2318 (similarity: 0.952)
#   - KG Entity 4671 (similarity: 0.948)
#
# Dialogue Entity: Entity_284
# Top matches:
#   - KG Entity 284 (similarity: 0.984)
#   - KG Entity 10721 (similarity: 0.951)
#   - KG Entity 3840 (similarity: 0.949)
#
# Dialogue Entity: Entity_285
# Top matches:
#   - KG Entity 285 (similarity: 0.990)
#   - KG Entity 11395 (similarity: 0.950)
#   - KG Entity 2501 (similarity: 0.949)
#
# Dialogue Entity: Entity_286
# Top matches:
#   - KG Entity 4683 (similarity: 0.952)
#   - KG Entity 10248 (similarity: 0.951)
#   - KG Entity 11628 (similarity: 0.951)
#
# Dialogue Entity: Entity_287
# Top matches:
#   - KG Entity 287 (similarity: 0.985)
#   - KG Entity 6381 (similarity: 0.954)
#   - KG Entity 5276 (similarity: 0.950)
#
# Dialogue Entity: Entity_288
# Top matches:
#   - KG Entity 288 (similarity: 0.990)
#   - KG Entity 10218 (similarity: 0.955)
#   - KG Entity 6884 (similarity: 0.954)
#
# Dialogue Entity: Entity_289
# Top matches:
#   - KG Entity 289 (similarity: 0.951)
#   - KG Entity 2672 (similarity: 0.951)
#   - KG Entity 4546 (similarity: 0.950)
#
# Dialogue Entity: Entity_290
# Top matches:
#   - KG Entity 290 (similarity: 1.000)
#   - KG Entity 3682 (similarity: 0.949)
#   - KG Entity 5535 (similarity: 0.949)
#
# Dialogue Entity: Entity_291
# Top matches:
#   - KG Entity 291 (similarity: 1.000)
#   - KG Entity 11543 (similarity: 0.952)
#   - KG Entity 10803 (similarity: 0.951)
#
# Dialogue Entity: Entity_292
# Top matches:
#   - KG Entity 292 (similarity: 0.954)
#   - KG Entity 8797 (similarity: 0.951)
#   - KG Entity 6936 (similarity: 0.948)
#
# Dialogue Entity: Entity_293
# Top matches:
#   - KG Entity 293 (similarity: 0.959)
#   - KG Entity 5628 (similarity: 0.952)
#   - KG Entity 3380 (similarity: 0.950)
#
# Dialogue Entity: Entity_294
# Top matches:
#   - KG Entity 10197 (similarity: 0.952)
#   - KG Entity 7729 (similarity: 0.949)
#   - KG Entity 9269 (similarity: 0.948)
#
# Dialogue Entity: Entity_295
# Top matches:
#   - KG Entity 295 (similarity: 1.000)
#   - KG Entity 4571 (similarity: 0.952)
#   - KG Entity 10603 (similarity: 0.949)
#
# Dialogue Entity: Entity_296
# Top matches:
#   - KG Entity 296 (similarity: 1.000)
#   - KG Entity 6683 (similarity: 0.950)
#   - KG Entity 731 (similarity: 0.948)
#
# Dialogue Entity: Entity_297
# Top matches:
#   - KG Entity 297 (similarity: 1.000)
#   - KG Entity 7496 (similarity: 0.958)
#   - KG Entity 11420 (similarity: 0.956)
#
# Dialogue Entity: Entity_298
# Top matches:
#   - KG Entity 298 (similarity: 1.000)
#   - KG Entity 4979 (similarity: 0.954)
# ...
#   - KG Entity 2866 (similarity: 0.948)
#   - KG Entity 4082 (similarity: 0.947)
#
# Dialogue Entity: Entity_11763
# Top matches:
#   - KG Entity 11763 (similarity: 1.000)
#   - KG Entity 9307 (similarity: 0.954)
#   - KG Entity 9400 (similarity: 0.954)
#
# Dialogue Entity: Entity_11764
# Top matches:
#   - KG Entity 11764 (similarity: 1.000)
#   - KG Entity 7031 (similarity: 0.951)
#   - KG Entity 11241 (similarity: 0.951)
#
# Dialogue Entity: Entity_11765
# Top matches:
#   - KG Entity 11765 (similarity: 1.000)
#   - KG Entity 4031 (similarity: 0.953)
#   - KG Entity 6561 (similarity: 0.952)
#
# Dialogue Entity: Entity_11766
# Top matches:
#   - KG Entity 11766 (similarity: 1.000)
#   - KG Entity 10442 (similarity: 0.955)
#   - KG Entity 866 (similarity: 0.954)
#
# Dialogue Entity: Entity_11767
# Top matches:
#   - KG Entity 11767 (similarity: 1.000)
#   - KG Entity 830 (similarity: 0.951)
#   - KG Entity 4364 (similarity: 0.950)
#
# Dialogue Entity: Entity_11768
# Top matches:
#   - KG Entity 11768 (similarity: 1.000)
#   - KG Entity 2003 (similarity: 0.950)
#   - KG Entity 10702 (similarity: 0.947)
#
# Dialogue Entity: Entity_11769
# Top matches:
#   - KG Entity 11769 (similarity: 1.000)
#   - KG Entity 4158 (similarity: 0.948)
#   - KG Entity 7291 (similarity: 0.948)
#
# Dialogue Entity: Entity_11770
# Top matches:
#   - KG Entity 11770 (similarity: 1.000)
#   - KG Entity 2851 (similarity: 0.949)
#   - KG Entity 11702 (similarity: 0.949)
#
# Dialogue Entity: Entity_11771
# Top matches:
#   - KG Entity 11771 (similarity: 1.000)
#   - KG Entity 3863 (similarity: 0.950)
#   - KG Entity 1791 (similarity: 0.948)
#
# Dialogue Entity: Entity_11772
# Top matches:
#   - KG Entity 11772 (similarity: 1.000)
#   - KG Entity 7941 (similarity: 0.952)
#   - KG Entity 2730 (similarity: 0.950)
#
# Dialogue Entity: Entity_11773
# Top matches:
#   - KG Entity 11773 (similarity: 1.000)
#   - KG Entity 11739 (similarity: 0.951)
#   - KG Entity 5001 (similarity: 0.951)
#
# Dialogue Entity: Entity_11774
# Top matches:
#   - KG Entity 11774 (similarity: 1.000)
#   - KG Entity 11498 (similarity: 0.949)
#   - KG Entity 8815 (similarity: 0.948)
#
# Dialogue Entity: Entity_11775
# Top matches:
#   - KG Entity 11775 (similarity: 1.000)
#   - KG Entity 5916 (similarity: 0.951)
#   - KG Entity 2104 (similarity: 0.950)
#
# Dialogue Entity: Entity_11776
# Top matches:
#   - KG Entity 11776 (similarity: 1.000)
#   - KG Entity 3877 (similarity: 0.951)
#   - KG Entity 10721 (similarity: 0.951)
#
# Dialogue Entity: Entity_11777
# Top matches:
#   - KG Entity 11777 (similarity: 1.000)
#   - KG Entity 11612 (similarity: 0.958)
#   - KG Entity 6977 (similarity: 0.953)
#
# Dialogue Entity: Entity_11778
# Top matches:
#   - KG Entity 11778 (similarity: 1.000)
#   - KG Entity 10442 (similarity: 0.948)
#   - KG Entity 6381 (similarity: 0.947)
#
# Dialogue Entity: Entity_11779
# Top matches:
#   - KG Entity 11779 (similarity: 1.000)
#   - KG Entity 3018 (similarity: 0.949)
#   - KG Entity 4032 (similarity: 0.949)
#
# Dialogue Entity: Entity_11780
# Top matches:
#   - KG Entity 11780 (similarity: 1.000)
#   - KG Entity 7126 (similarity: 0.953)
#   - KG Entity 4683 (similarity: 0.951)
#
# Dialogue Entity: Entity_11781
# Top matches:
#   - KG Entity 11781 (similarity: 1.000)
#   - KG Entity 3938 (similarity: 0.949)
#   - KG Entity 10098 (similarity: 0.949)
#
# Dialogue Entity: Entity_11782
# Top matches:
#   - KG Entity 11782 (similarity: 1.000)
#   - KG Entity 2609 (similarity: 0.950)
#   - KG Entity 5822 (similarity: 0.949)
#
# Dialogue Entity: Entity_11783
# Top matches:
#   - KG Entity 11783 (similarity: 1.000)
#   - KG Entity 7448 (similarity: 0.951)
#   - KG Entity 8225 (similarity: 0.950)
#
# Dialogue Entity: Entity_11784
# Top matches:
#   - KG Entity 11784 (similarity: 1.000)
#   - KG Entity 11597 (similarity: 0.949)
#   - KG Entity 10781 (similarity: 0.948)
#
# Dialogue Entity: Entity_11785
# Top matches:
#   - KG Entity 11785 (similarity: 1.000)
#   - KG Entity 9832 (similarity: 0.951)
#   - KG Entity 7619 (similarity: 0.950)
#
# Dialogue Entity: Entity_11786
# Top matches:
#   - KG Entity 11786 (similarity: 1.000)
#   - KG Entity 1940 (similarity: 0.951)
#   - KG Entity 11713 (similarity: 0.950)
#
# Dialogue Entity: Entity_11787
# Top matches:
#   - KG Entity 11787 (similarity: 1.000)
#   - KG Entity 1939 (similarity: 0.951)
#   - KG Entity 8113 (similarity: 0.951)
#
# Dialogue Entity: Entity_11788
# Top matches:
#   - KG Entity 11788 (similarity: 1.000)
#   - KG Entity 6189 (similarity: 0.953)
#   - KG Entity 1293 (similarity: 0.952)
#
# Dialogue Entity: Entity_11789
# Top matches:
#   - KG Entity 11789 (similarity: 1.000)
#   - KG Entity 7818 (similarity: 0.954)
#   - KG Entity 2611 (similarity: 0.953)
#
# Dialogue Entity: Entity_11790
# Top matches:
#   - KG Entity 11790 (similarity: 1.000)
#   - KG Entity 923 (similarity: 0.955)
#   - KG Entity 4326 (similarity: 0.949)
#
# Dialogue Entity: Entity_11791
# Top matches:
#   - KG Entity 11791 (similarity: 1.000)
#   - KG Entity 9657 (similarity: 0.950)
#   - KG Entity 11694 (similarity: 0.949)
#
# Dialogue Entity: Entity_11792
# Top matches:
#   - KG Entity 11792 (similarity: 1.000)
#   - KG Entity 5244 (similarity: 0.954)
#   - KG Entity 10158 (similarity: 0.952)
#
# Dialogue Entity: Entity_11793
# Top matches:
#   - KG Entity 11793 (similarity: 1.000)
#   - KG Entity 8499 (similarity: 0.954)
#   - KG Entity 9769 (similarity: 0.949)
#
# Dialogue Entity: Entity_11794
# Top matches:
#   - KG Entity 11794 (similarity: 1.000)
#   - KG Entity 9986 (similarity: 0.949)
#   - KG Entity 11420 (similarity: 0.949)
#
# Dialogue Entity: Entity_11795
# Top matches:
#   - KG Entity 11795 (similarity: 1.000)
#   - KG Entity 4106 (similarity: 0.954)
#   - KG Entity 8543 (similarity: 0.952)
#
# Dialogue Entity: Entity_11796
# Top matches:
#   - KG Entity 11796 (similarity: 1.000)
#   - KG Entity 298 (similarity: 0.947)
#   - KG Entity 4979 (similarity: 0.946)
#
# Dialogue Entity: Entity_11797
# Top matches:
#   - KG Entity 11797 (similarity: 1.000)
#   - KG Entity 8437 (similarity: 0.955)
#   - KG Entity 10029 (similarity: 0.953)
#
# Dialogue Entity: Entity_11798
# Top matches:
#   - KG Entity 11798 (similarity: 1.000)
#   - KG Entity 7108 (similarity: 0.950)
#   - KG Entity 4350 (similarity: 0.949)
#
# Dialogue Entity: Entity_11799
# Top matches:
#   - KG Entity 11799 (similarity: 1.000)
#   - KG Entity 5608 (similarity: 0.946)
#   - KG Entity 7640 (similarity: 0.943)
#
# Dialogue Entity: Entity_11800
# Top matches:
#   - KG Entity 11800 (similarity: 1.000)
#   - KG Entity 3485 (similarity: 0.955)
#   - KG Entity 8252 (similarity: 0.954)
#
# Dialogue Entity: Entity_11801
# Top matches:
#   - KG Entity 11801 (similarity: 1.000)
#   - KG Entity 9005 (similarity: 0.951)
#   - KG Entity 9361 (similarity: 0.950)
#
# Dialogue Entity: Entity_11802
# Top matches:
#   - KG Entity 11802 (similarity: 1.000)
#   - KG Entity 341 (similarity: 0.952)
#   - KG Entity 9596 (similarity: 0.950)
#
# Dialogue Entity: Entity_11803
# Top matches:
#   - KG Entity 11803 (similarity: 1.000)
#   - KG Entity 6079 (similarity: 0.952)
#   - KG Entity 3931 (similarity: 0.949)
#
# Dialogue Entity: Entity_11804
# Top matches:
#   - KG Entity 11804 (similarity: 1.000)
#   - KG Entity 10442 (similarity: 0.953)
#   - KG Entity 8849 (similarity: 0.953)
#
# Dialogue Entity: Entity_11805
# Top matches:
#   - KG Entity 11805 (similarity: 1.000)
#   - KG Entity 5776 (similarity: 0.952)
#   - KG Entity 11698 (similarity: 0.951)
#
# Dialogue Entity: Entity_11806
# Top matches:
#   - KG Entity 11806 (similarity: 1.000)
#   - KG Entity 3319 (similarity: 0.955)
#   - KG Entity 10507 (similarity: 0.951)
#
# Dialogue Entity: Entity_11807
# Top matches:
#   - KG Entity 11807 (similarity: 1.000)
#   - KG Entity 10603 (similarity: 0.953)
#   - KG Entity 9955 (similarity: 0.952)
#
# Dialogue Entity: Entity_11808
# Top matches:
#   - KG Entity 11808 (similarity: 1.000)
#   - KG Entity 11183 (similarity: 0.954)
#   - KG Entity 10442 (similarity: 0.954)
#
# Dialogue Entity: Entity_11809
# Top matches:
#   - KG Entity 11809 (similarity: 1.000)
#   - KG Entity 8566 (similarity: 0.954)
#   - KG Entity 5207 (similarity: 0.953)
#
# Dialogue Entity: Entity_11810
# Top matches:
#   - KG Entity 11810 (similarity: 1.000)
#   - KG Entity 4356 (similarity: 0.952)
#   - KG Entity 3466 (similarity: 0.950)
#
# Dialogue Entity: Entity_11811
# Top matches:
#   - KG Entity 11811 (similarity: 1.000)
#   - KG Entity 8071 (similarity: 0.950)
#   - KG Entity 6236 (similarity: 0.949)
#
# Dialogue Entity: Entity_11812
# Top matches:
#   - KG Entity 11812 (similarity: 1.000)
#   - KG Entity 9832 (similarity: 0.949)
#   - KG Entity 7775 (similarity: 0.949)
#
# Dialogue Entity: Entity_11813
# Top matches:
#   - KG Entity 11813 (similarity: 1.000)
#   - KG Entity 10175 (similarity: 0.948)
#   - KG Entity 6949 (similarity: 0.947)
#
# Dialogue Entity: Entity_11814
# Top matches:
#   - KG Entity 11814 (similarity: 1.000)
#   - KG Entity 10134 (similarity: 0.946)
#   - KG Entity 1219 (similarity: 0.946)
#
# Dialogue Entity: Entity_11815
# Top matches:
#   - KG Entity 11815 (similarity: 1.000)
#   - KG Entity 7654 (similarity: 0.951)
#   - KG Entity 9741 (similarity: 0.949)
#
# Dialogue Entity: Entity_11816
# Top matches:
#   - KG Entity 11816 (similarity: 1.000)
#   - KG Entity 7496 (similarity: 0.949)
#   - KG Entity 8705 (similarity: 0.948)
#
# Dialogue Entity: Entity_11817
# Top matches:
#   - KG Entity 11817 (similarity: 1.000)
#   - KG Entity 2497 (similarity: 0.946)
#   - KG Entity 9041 (similarity: 0.943)
#
# Dialogue Entity: Entity_11818
# Top matches:
#   - KG Entity 11818 (similarity: 1.000)
#   - KG Entity 3869 (similarity: 0.954)
#   - KG Entity 5446 (similarity: 0.951)
#
# Dialogue Entity: Entity_11819
# Top matches:
#   - KG Entity 11819 (similarity: 1.000)
#   - KG Entity 1117 (similarity: 0.950)
#   - KG Entity 6633 (similarity: 0.948)
#
# Dialogue Entity: Entity_11820
# Top matches:
#   - KG Entity 11820 (similarity: 1.000)
#   - KG Entity 9400 (similarity: 0.951)
#   - KG Entity 9096 (similarity: 0.950)
#
# Dialogue Entity: Entity_11821
# Top matches:
#   - KG Entity 11821 (similarity: 1.000)
#   - KG Entity 9842 (similarity: 0.949)
#   - KG Entity 11212 (similarity: 0.948)
#
# Dialogue Entity: Entity_11822
# Top matches:
#   - KG Entity 11822 (similarity: 1.000)
#   - KG Entity 6694 (similarity: 0.952)
#   - KG Entity 7767 (similarity: 0.949)
#
# Dialogue Entity: Entity_11823
# Top matches:
#   - KG Entity 11823 (similarity: 1.000)
#   - KG Entity 4041 (similarity: 0.949)
#   - KG Entity 1677 (similarity: 0.949)
#
# Dialogue Entity: Entity_11824
# Top matches:
#   - KG Entity 11824 (similarity: 1.000)
#   - KG Entity 5052 (similarity: 0.946)
#   - KG Entity 4105 (similarity: 0.946)
#
# Dialogue Entity: Entity_11825
# Top matches:
#   - KG Entity 11825 (similarity: 1.000)
#   - KG Entity 7830 (similarity: 0.952)
#   - KG Entity 5066 (similarity: 0.952)
#
# Dialogue Entity: Entity_11826
# Top matches:
#   - KG Entity 11826 (similarity: 1.000)
#   - KG Entity 3190 (similarity: 0.952)
#   - KG Entity 7496 (similarity: 0.949)
#
# Dialogue Entity: Entity_11827
# Top matches:
#   - KG Entity 11827 (similarity: 1.000)
#   - KG Entity 6677 (similarity: 0.949)
#   - KG Entity 7059 (similarity: 0.947)
#
# Dialogue Entity: Entity_11828
# Top matches:
#   - KG Entity 11828 (similarity: 1.000)
#   - KG Entity 9829 (similarity: 0.948)
#   - KG Entity 5973 (similarity: 0.945)
#
# Dialogue Entity: Entity_11829
# Top matches:
#   - KG Entity 11829 (similarity: 1.000)
#   - KG Entity 9384 (similarity: 0.954)
#   - KG Entity 5196 (similarity: 0.951)
#
# Dialogue Entity: Entity_11830
# Top matches:
#   - KG Entity 11830 (similarity: 1.000)
#   - KG Entity 8871 (similarity: 0.952)
#   - KG Entity 9762 (similarity: 0.948)
#
# Dialogue Entity: Entity_11831
# Top matches:
#   - KG Entity 11831 (similarity: 1.000)
#   - KG Entity 5245 (similarity: 0.954)
#   - KG Entity 10876 (similarity: 0.953)
#
# Dialogue Entity: Entity_11832
# Top matches:
#   - KG Entity 11832 (similarity: 1.000)
#   - KG Entity 5932 (similarity: 0.952)
#   - KG Entity 2037 (similarity: 0.952)
#
# Dialogue Entity: Entity_11833
# Top matches:
#   - KG Entity 11833 (similarity: 1.000)
#   - KG Entity 4979 (similarity: 0.958)
#   - KG Entity 9206 (similarity: 0.956)
#
# Dialogue Entity: Entity_11834
# Top matches:
#   - KG Entity 11834 (similarity: 1.000)
#   - KG Entity 10442 (similarity: 0.948)
#   - KG Entity 9596 (similarity: 0.948)
#
# Dialogue Entity: Entity_11835
# Top matches:
#   - KG Entity 11835 (similarity: 1.000)
#   - KG Entity 5365 (similarity: 0.953)
#   - KG Entity 1811 (similarity: 0.953)
#
# Dialogue Entity: Entity_11836
# Top matches:
#   - KG Entity 11836 (similarity: 1.000)
#   - KG Entity 1528 (similarity: 0.954)
#   - KG Entity 8621 (similarity: 0.952)
#
# Dialogue Entity: Entity_11837
# Top matches:
#   - KG Entity 11837 (similarity: 1.000)
#   - KG Entity 9769 (similarity: 0.952)
#   - KG Entity 9107 (similarity: 0.951)
#
# Dialogue Entity: Entity_11838
# Top matches:
#   - KG Entity 11838 (similarity: 1.000)
#   - KG Entity 5803 (similarity: 0.953)
#   - KG Entity 10877 (similarity: 0.953)
#
# Dialogue Entity: Entity_11839
# Top matches:
#   - KG Entity 11839 (similarity: 1.000)
#   - KG Entity 8589 (similarity: 0.948)
#   - KG Entity 11246 (similarity: 0.948)
#
# Dialogue Entity: Entity_11840
# Top matches:
#   - KG Entity 11840 (similarity: 1.000)
#   - KG Entity 8871 (similarity: 0.952)
#   - KG Entity 6353 (similarity: 0.952)
#
# Dialogue Entity: Entity_11841
# Top matches:
#   - KG Entity 11841 (similarity: 1.000)
#   - KG Entity 7154 (similarity: 0.948)
#   - KG Entity 7748 (similarity: 0.948)
#
# Dialogue Entity: Entity_11842
# Top matches:
#   - KG Entity 11842 (similarity: 1.000)
#   - KG Entity 7219 (similarity: 0.949)
#   - KG Entity 2613 (similarity: 0.946)
#
# Dialogue Entity: Entity_11843
# Top matches:
#   - KG Entity 11843 (similarity: 1.000)
#   - KG Entity 9647 (similarity: 0.944)
#   - KG Entity 6926 (similarity: 0.944)
#
# Dialogue Entity: Entity_11844
# Top matches:
#   - KG Entity 11844 (similarity: 1.000)
#   - KG Entity 10472 (similarity: 0.951)
#   - KG Entity 10786 (similarity: 0.949)
#
# Dialogue Entity: Entity_11845
# Top matches:
#   - KG Entity 11845 (similarity: 1.000)
#   - KG Entity 4132 (similarity: 0.952)
#   - KG Entity 10442 (similarity: 0.952)
#
# Dialogue Entity: Entity_11846
# Top matches:
#   - KG Entity 11846 (similarity: 1.000)
#   - KG Entity 3708 (similarity: 0.945)
#   - KG Entity 7423 (similarity: 0.944)
#
# Dialogue Entity: Entity_11847
# Top matches:
#   - KG Entity 11847 (similarity: 1.000)
#   - KG Entity 7617 (similarity: 0.952)
#   - KG Entity 2701 (similarity: 0.952)
#
# Dialogue Entity: Entity_11848
# Top matches:
#   - KG Entity 11848 (similarity: 1.000)
#   - KG Entity 11766 (similarity: 0.952)
#   - KG Entity 7403 (similarity: 0.949)
#
# Dialogue Entity: Entity_11849
# Top matches:
#   - KG Entity 11849 (similarity: 1.000)
#   - KG Entity 3065 (similarity: 0.953)
#   - KG Entity 11668 (similarity: 0.952)
#
# Dialogue Entity: Entity_11850
# Top matches:
#   - KG Entity 11850 (similarity: 1.000)
#   - KG Entity 8150 (similarity: 0.952)
#   - KG Entity 3731 (similarity: 0.948)
#
# Dialogue Entity: Entity_11851
# Top matches:
#   - KG Entity 11851 (similarity: 1.000)
#   - KG Entity 9983 (similarity: 0.952)
#   - KG Entity 991 (similarity: 0.952)
#
# Dialogue Entity: Entity_11852
# Top matches:
#   - KG Entity 11852 (similarity: 1.000)
#   - KG Entity 8252 (similarity: 0.954)
#   - KG Entity 5772 (similarity: 0.952)
#
# Dialogue Entity: Entity_11853
# Top matches:
#   - KG Entity 11853 (similarity: 1.000)
#   - KG Entity 6777 (similarity: 0.951)
#   - KG Entity 8492 (similarity: 0.950)
#
# Dialogue Entity: Entity_11854
# Top matches:
#   - KG Entity 11854 (similarity: 1.000)
#   - KG Entity 9360 (similarity: 0.945)
#   - KG Entity 11749 (similarity: 0.944)
#
# Dialogue Entity: Entity_11855
# Top matches:
#   - KG Entity 11855 (similarity: 1.000)
#   - KG Entity 9714 (similarity: 0.949)
#   - KG Entity 10075 (similarity: 0.948)
#
# Dialogue Entity: Entity_11856
# Top matches:
#   - KG Entity 11856 (similarity: 1.000)
#   - KG Entity 8397 (similarity: 0.950)
#   - KG Entity 7653 (similarity: 0.949)
#
# Dialogue Entity: Entity_11857
# Top matches:
#   - KG Entity 11857 (similarity: 1.000)
#   - KG Entity 10139 (similarity: 0.956)
#   - KG Entity 3275 (similarity: 0.955)
#
# Dialogue Entity: Entity_11858
# Top matches:
#   - KG Entity 11858 (similarity: 1.000)
#   - KG Entity 4105 (similarity: 0.948)
#   - KG Entity 4882 (similarity: 0.947)
#
# Dialogue Entity: Entity_11859
# Top matches:
#   - KG Entity 11859 (similarity: 1.000)
#   - KG Entity 3453 (similarity: 0.950)
#   - KG Entity 7369 (similarity: 0.949)
#
# Dialogue Entity: Entity_11860
# Top matches:
#   - KG Entity 11860 (similarity: 1.000)
#   - KG Entity 10721 (similarity: 0.950)
#   - KG Entity 11006 (similarity: 0.949)
